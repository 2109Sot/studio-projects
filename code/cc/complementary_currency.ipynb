# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
# %matplotlib inline

# %%
# raw_html = urlopen("http://complementarycurrency.org/ccDatabase/les_public_splash.php?action=list&which=0&list=r").read()
# doc = BeautifulSoup(raw_html, "html.parser")

# %%
# doc

# %%
# my_table = doc.find("table", attrs={"width": "100%"})
# each_entry = my_table.find_all('tr')[4:34]

# %%
#each_entry

# %%
entries = []
for page in range(0,11):
    driver = webdriver.Chrome()
    driver.get("http://complementarycurrency.org/ccDatabase/les_public_splash.php?action=list&which=" + str(page) + "&list=r")
    html = driver.page_source
    doc = BeautifulSoup(html, 'html.parser')
    my_table = doc.find("table", attrs={"width": "100%"})
    each_entry = my_table.find_all('tr')[4:34]
    for entry in each_entry:
        ENTRY_DICT = {}
        entry_name = entry.find_all('ul')[0].find('a')
        if entry_name:
            #print(entry_name.text.strip())
            ENTRY_DICT['system_name'] = entry_name.text.strip()
        entry_type = entry.find_all('ul')[0].find('li')
        if entry_type:
            #print(entry_type.text.strip())
            ENTRY_DICT['system_type'] = entry_type.text.strip()
        entry_origin = entry.find_all('td')[2]
        if entry_origin:
            #print(entry_origin.text.strip())
            ENTRY_DICT['system_origin'] = entry_origin.text.strip()
        entry_serving = entry.find_all('td')[1]
        if entry_serving:
            #print(entry_serving.text.strip())
            ENTRY_DICT['system_serving'] = entry_serving.text.strip()
        entry_year_of_establishment = entry.find_all('td')[3]
        if entry_year_of_establishment:
            #print(entry_year_of_establishment.text.strip())
            ENTRY_DICT['establishment'] = entry_year_of_establishment.text.strip()
        entries.append(ENTRY_DICT)
        print(ENTRY_DICT)
        print("-----")
# Out:
# {'system_name': 'Hourcoin', 'system_type': 'Hourcoin\n\nBlock chain crypto-currency', 'system_origin': 'United Kingdom', 'system_serving': 'Wales', 'establishment': '2017-05-28'}
# -----
# {'system_name': 'Timebank.cc', 'system_type': 'Timebank.cc\n\nTime Bank System', 'system_origin': 'Netherlands', 'system_serving': 'The Hague - Brussels - Lisbon', 'establishment': '2017-04-07'}
# -----
# {'system_name': 'COOPEK', 'system_type': 'COOPEK\n\nGlobal financial currency', 'system_origin': 'France', 'system_serving': 'COOPEK', 'establishment': '2017-02-13'}
# -----
# {'system_name': 'Compumatrix powered by Bitshares 2.0', 'system_type': 'Compumatrix powered by Bitshares 2.0\n\nBlock chain crypto-currency', 'system_origin': 'United States', 'system_serving': 'Worldwide', 'establishment': '2017-02-07'}
# -----
# {'system_name': 'Kasonga Business Network', 'system_type': 'Kasonga Business Network\n\nVoucher Currency System', 'system_origin': 'Kenya', 'system_serving': 'Kyangwali Refugee Settlement', 'establishment': '2017-01-28'}
# -----
# {'system_name': 'Red Rizoma', 'system_type': 'Red Rizoma\n\nCommunity Exchange System', 'system_origin': 'Argentina', 'system_serving': 'Córdoba', 'establishment': '2016-11-15'}
# -----
# {'system_name': 'ICU P2P Payment', 'system_type': 'ICU P2P Payment\n\nGlobal financial currency', 'system_origin': 'Spain', 'system_serving': 'Worldwide', 'establishment': '2016-07-16'}
# -----
# {'system_name': 'bambali.de', 'system_type': 'bambali.de\n\nMarketplace Currency (ie. RGT)', 'system_origin': 'Germany', 'system_serving': 'Deutschland', 'establishment': '2016-05-15'}
# -----
# {'system_name': 'Red de Intercambio Solidario Saja', 'system_type': 'Red de Intercambio Solidario Saja\n\nCommunity Exchange System', 'system_origin': 'Spain', 'system_serving': 'Cantabria', 'establishment': '2016-03-06'}
# -----
# {'system_name': 'www.ces.org.za', 'system_type': 'www.ces.org.za\n\nCommunity Exchange System', 'system_origin': 'Spain', 'system_serving': 'Zaragoza', 'establishment': '2016-02-18'}
# -----
# {'system_name': 'Der Regio', 'system_type': 'Der Regio\n\nVoucher Currency System', 'system_origin': 'Germany', 'system_serving': 'München', 'establishment': '2016-02-10'}
# -----
# {'system_name': 'Myyrmäen Aikapankki', 'system_type': 'Myyrmäen Aikapankki\n\nCommunity Exchange System', 'system_origin': 'Finland', 'system_serving': 'Myyrmäen suuralue', 'establishment': '2016-01-29'}
# -----
# {'system_name': 'Colu', 'system_type': 'Colu\n\nBlock chain crypto-currency', 'system_origin': 'Israel', 'system_serving': 'Colu', 'establishment': '2016-01-26'}
# -----
# {'system_name': 'TimesFree', 'system_type': 'TimesFree\n\nCommunity Cooperation System', 'system_origin': 'United States', 'system_serving': 'Worldwide', 'establishment': '2015-12-26'}
# -----
# {'system_name': 'CES Greater Vancouver', 'system_type': 'CES Greater Vancouver\n\nCommunity Exchange System', 'system_origin': 'Canada', 'system_serving': 'Greater Vancouver', 'establishment': '2015-12-18'}
# -----
# {'system_name': 'Community Exchange System - Alaska ExchangeNetwork', 'system_type': 'Community Exchange System - Alaska ExchangeNetwork\n\nCommunity Exchange System', 'system_origin': 'United States', 'system_serving': 'Alaska', 'establishment': '2015-12-17'}
# -----
# {'system_name': 'Bitcoin', 'system_type': 'Bitcoin\n\nCryptocurrency', 'system_origin': 'Israel', 'system_serving': 'bitcoin Community', 'establishment': '2015-12-15'}
# -----
# {'system_name': 'Thames Green Dollar Exchange', 'system_type': 'Thames Green Dollar Exchange\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'New Zealand', 'system_serving': 'Thames', 'establishment': '2015-12-14'}
# -----
# {'system_name': 'Copín', 'system_type': 'Copín\n\nCommunity Exchange System', 'system_origin': 'Spain', 'system_serving': 'Asturias', 'establishment': '2015-12-14'}
# -----
# {'system_name': 'TIME BANKING', 'system_type': 'TIME BANKING\n\nCommunity Barter System', 'system_origin': 'South Africa', 'system_serving': 'CAMEROUNAISE', 'establishment': '2015-12-14'}
# -----
# {'system_name': 'Community Exchange System', 'system_type': 'Community Exchange System\n\nLETSystem', 'system_origin': 'Canada', 'system_serving': 'Revelstoke Alternative Goods and Services Exchange', 'establishment': '2015-12-14'}
# -----
# {'system_name': 'EcoXarxa Plana Baixa', 'system_type': 'EcoXarxa Plana Baixa\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Spain', 'system_serving': 'Comunidad Valenciana', 'establishment': '2015-12-08'}
# -----
# {'system_name': 'Collective Currency', 'system_type': 'Collective Currency\n\nMutual Credit System', 'system_origin': 'Barbados', 'system_serving': 'St. James', 'establishment': '2015-11-30'}
# -----
# {'system_name': 'Hudson Valley Current', 'system_type': 'Hudson Valley Current\n\nCommunity Barter System', 'system_origin': 'United States', 'system_serving': 'Hudson Valley', 'establishment': '2015-11-17'}
# -----
# {'system_name': 'KoiNo', 'system_type': 'KoiNo\n\nLETSystem', 'system_origin': 'Greece', 'system_serving': 'Kalamaria/Thessaloniki', 'establishment': '2015-11-09'}
# -----
# {'system_name': 'Kapital Truth', 'system_type': 'Kapital Truth\n\nReconocimiento diario de mérito mutuo', 'system_origin': 'Spain', 'system_serving': 'Global', 'establishment': '2015-11-05'}
# -----
# {'system_name': 'BBX', 'system_type': 'BBX\n\nCommercial Exchange System', 'system_origin': 'Hong Kong', 'system_serving': 'Global', 'establishment': '2015-08-17'}
# -----
# {'system_name': 'ECU _ Alternative Currency', 'system_type': 'ECU _ Alternative Currency\n\nGlobal financial currency', 'system_origin': 'United States', 'system_serving': 'worldwide', 'establishment': '2015-08-08'}
# -----
# {'system_name': 'Tibex', 'system_type': 'Tibex\n\nCommercial Exchange System', 'system_origin': 'Italy', 'system_serving': 'Lazio', 'establishment': '2015-05-27'}
# -----
# {'system_name': 'Nuevo', 'system_type': 'Nuevo\n\nCommunity Barter System', 'system_origin': 'Guatemala', 'system_serving': 'Quetzaltenango', 'establishment': '2015-05-11'}
# -----
# {'system_name': 'Estrela Community Exchange', 'system_type': 'Estrela Community Exchange\n\nMutual Credit System', 'system_origin': 'Portugal', 'system_serving': 'Beiras', 'establishment': '2015-04-22'}
# -----
# {'system_name': 'ZIPcoin', 'system_type': 'ZIPcoin\n\nECO-COIN and LOYALTY hybrid', 'system_origin': 'Italy', 'system_serving': 'Lazio', 'establishment': '2015-04-09'}
# -----
# {'system_name': 'Pendo', 'system_type': 'Pendo\n\nCommunity Exchange System', 'system_origin': 'Netherlands', 'system_serving': 'Pendo', 'establishment': '2015-03-30'}
# -----
# {'system_name': 'rCredits', 'system_type': 'rCredits\n\nMutual Credit Hybrid', 'system_origin': 'United States', 'system_serving': 'Greenfield, MA', 'establishment': '2015-03-24'}
# -----
# {'system_name': 'Star Dollar', 'system_type': 'Star Dollar\n\nCommodity Based System', 'system_origin': 'United States', 'system_serving': 'Untied States of America', 'establishment': '2015-03-15'}
# -----
# {'system_name': 'Credits', 'system_type': 'Credits\n\nTransaction Software', 'system_origin': 'Czech Republic', 'system_serving': 'Multiversum Online', 'establishment': '2015-02-06'}
# -----
# {'system_name': 'Alternative Choice', 'system_type': 'Alternative Choice\n\nCommodity Based System', 'system_origin': 'Australia', 'system_serving': 'Global', 'establishment': '2015-01-25'}
# -----
# {'system_name': 'Warren Money', 'system_type': 'Warren Money\n\nFiat money (Warrens)?', 'system_origin': 'Australia', 'system_serving': 'Manjimup Shire', 'establishment': '2015-01-08'}
# -----
# {'system_name': 'Ecotracte', 'system_type': "Ecotracte\n\nSystème d'échange local LETS/SEL", 'system_origin': 'Spain', 'system_serving': 'Catalunya', 'establishment': '2015-01-04'}
# -----
# {'system_name': 'WE', 'system_type': 'WE\n\nGlobal financial currency', 'system_origin': 'Germany', 'system_serving': 'International', 'establishment': '2014-10-15'}
# -----
# {'system_name': 'Nofiatcoin', 'system_type': 'Nofiatcoin\n\nCryptographic Currency', 'system_origin': 'Dominican Republic', 'system_serving': 'Global', 'establishment': '2014-09-01'}
# -----
# {'system_name': 'Blue Mountains Community Exchange', 'system_type': 'Blue Mountains Community Exchange\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'Blue Mountains', 'establishment': '2014-08-22'}
# -----
# {'system_name': 'Letsapen', 'system_type': 'Letsapen\n\nLETSystem', 'system_origin': 'Belgium', 'system_serving': 'Antwerpen binnenstad', 'establishment': '2014-08-21'}
# -----
# {'system_name': 'CREVIT', 'system_type': 'CREVIT\n\nFiat Currency System', 'system_origin': 'Italy', 'system_serving': 'Italia', 'establishment': '2014-08-16'}
# -----
# {'system_name': 'Kawartha Loon Exchange', 'system_type': 'Kawartha Loon Exchange\n\nFiat Currency System', 'system_origin': 'Canada', 'system_serving': 'Peterborough', 'establishment': '2014-06-28'}
# -----
# {'system_name': 'WeCoin', 'system_type': 'WeCoin\n\nCommunity Cooperation System', 'system_origin': 'Italy', 'system_serving': 'international', 'establishment': '2014-06-25'}
# -----
# {'system_name': 'Action Pounds - The People', 'system_type': 'Action Pounds - The People\n\nMutual Credit System', 'system_origin': 'United Kingdom', 'system_serving': 'UK', 'establishment': '2014-06-20'}
# -----
# {'system_name': 'Bangla Pesa', 'system_type': 'Bangla Pesa\n\nMutual Credit System', 'system_origin': 'Kenya', 'system_serving': 'Bangladesh Slum', 'establishment': '2014-06-10'}
# -----
# {'system_name': 'Brick City Bucks', 'system_type': 'Brick City Bucks', 'system_origin': 'United States', 'system_serving': 'Greater Newark Region', 'establishment': '2014-06-04'}
# -----
# {'system_name': 'e-mane', 'system_type': 'e-mane\n\nMutual Credit System', 'system_origin': 'Australia', 'system_serving': 'Peter Eriksson Center', 'establishment': '2014-05-31'}
# -----
# {'system_name': 'Casova banka Praha', 'system_type': 'Casova banka Praha\n\nTime Bank System', 'system_origin': 'Czech Republic', 'system_serving': 'Casova banka Praha', 'establishment': '2014-02-26'}
# -----
# {'system_name': 'LETS Sint-Niklaas', 'system_type': 'LETS Sint-Niklaas\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Sint-Niklaas', 'establishment': '2014-02-14'}
# -----
# {'system_name': 'Evergreen', 'system_type': 'Evergreen\n\nCommunity Exchange System', 'system_origin': 'United States', 'system_serving': 'Evergreen', 'establishment': '2014-01-25'}
# -----
# {'system_name': 'tradeNOW', 'system_type': 'tradeNOW\n\nMarketplace Currency (ie. RGT)', 'system_origin': 'Greece', 'system_serving': 'internet barter system', 'establishment': '2014-01-24'}
# -----
# {'system_name': 'Star Dollar', 'system_type': 'Star Dollar', 'system_origin': 'United States', 'system_serving': 'all', 'establishment': '2013-11-21'}
# -----
# {'system_name': 'Timebanking', 'system_type': 'Timebanking\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Not Sure', 'establishment': '2013-10-29'}
# -----
# {'system_name': 'Wymiennik. Społecznościowy System Wymiany', 'system_type': 'Wymiennik. Społecznościowy System Wymiany\n\nCommunity Exchange System', 'system_origin': 'Poland', 'system_serving': 'Polish', 'establishment': '2013-10-16'}
# -----
# {'system_name': 'Communitas Capacity Exchange', 'system_type': 'Communitas Capacity Exchange\n\nMutual Credit System', 'system_origin': 'Canada', 'system_serving': 'Edmonton', 'establishment': '2013-09-30'}
# -----
# {'system_name': 'TEM (Local Exchange Unit) of Volos', 'system_type': 'TEM (Local Exchange Unit) of Volos\n\nLETSystem', 'system_origin': 'Greece', 'system_serving': 'Volos', 'establishment': '2013-09-16'}
# -----
# {'system_name': 'Dam', 'system_type': 'Dam\n\nMutual Credit System', 'system_origin': 'Netherlands', 'system_serving': 'Greater Rotterdam Area', 'establishment': '2013-08-17'}
# -----
# {'system_name': 'Australian Reserve Dollar', 'system_type': 'Australian Reserve Dollar\n\nFiat Currency System', 'system_origin': 'Australia', 'system_serving': 'Australia', 'establishment': '2013-08-08'}
# -----
# {'system_name': 'International Reserve Currency', 'system_type': 'International Reserve Currency\n\nFiat Currency System', 'system_origin': 'Hong Kong', 'system_serving': 'World Wide', 'establishment': '2013-08-08'}
# -----
# {'system_name': 'CENTs Tasmania', 'system_type': 'CENTs Tasmania\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'Tasmania', 'establishment': '2013-07-16'}
# -----
# {'system_name': 'P2P Time Bank', 'system_type': 'P2P Time Bank\n\nP2P Robust Complementary Community Currency System', 'system_origin': 'Ukraine', 'system_serving': 'Worldwide', 'establishment': '2013-05-26'}
# -----
# {'system_name': 'MeRa', 'system_type': 'MeRa\n\nPayment system', 'system_origin': 'Russia', 'system_serving': 'Cybercountry', 'establishment': '2013-05-24'}
# -----
# {'system_name': 'Bristol Pound', 'system_type': 'Bristol Pound\n\nFiat Currency System', 'system_origin': 'United Kingdom', 'system_serving': 'Bristol and Region', 'establishment': '2013-05-22'}
# -----
# {'system_name': 'Corporate Trade Network', 'system_type': 'Corporate Trade Network \n\nMutual Credit System', 'system_origin': 'Canada', 'system_serving': 'Business', 'establishment': '2013-05-14'}
# -----
# {'system_name': 'La Banque du Temps', 'system_type': "La Banque du Temps\n\nSystème d'échange local LETS/SEL", 'system_origin': 'Canada', 'system_serving': 'SEL-LETS sur la planète', 'establishment': '2013-04-08'}
# -----
# {'system_name': 'Corporate Trade Network', 'system_type': 'Corporate Trade Network \n\nMutual Credit System', 'system_origin': 'Canada', 'system_serving': 'Business', 'establishment': '2013-03-25'}
# -----
# {'system_name': 'LETS Mol', 'system_type': 'LETS Mol\n\nLETSystem', 'system_origin': 'Belgium', 'system_serving': 'Europa', 'establishment': '2013-03-20'}
# -----
# {'system_name': 'Corporate Trade Network', 'system_type': 'Corporate Trade Network \n\nMutual Credit System', 'system_origin': 'Canada', 'system_serving': 'Business', 'establishment': '2013-03-08'}
# -----
# {'system_name': 'Community Dollar Network', 'system_type': 'Community Dollar Network\n\nCommodity Based System', 'system_origin': 'United States', 'system_serving': 'Cabool, MO', 'establishment': '2013-03-08'}
# -----
# {'system_name': 'EPI', 'system_type': 'EPI\n\nMonnaie Locale Complémentaire (MLC)', 'system_origin': 'Belgium', 'system_serving': 'Epi Lorrain asbl', 'establishment': '2013-02-05'}
# -----
# {'system_name': 'Camuno', 'system_type': 'Camuno\n\nFiat Currency System', 'system_origin': 'Italy', 'system_serving': 'Camuno.Net', 'establishment': '2013-01-31'}
# -----
# {'system_name': 'Waterloo Region Time Exchange', 'system_type': 'Waterloo Region Time Exchange\n\nTime Bank System', 'system_origin': 'Canada', 'system_serving': 'Waterloo Region', 'establishment': '2013-01-09'}
# -----
# {'system_name': 'Powell River Dollar', 'system_type': 'Powell River Dollar\n\nCommunity Way', 'system_origin': 'Canada', 'system_serving': 'Powell River', 'establishment': '2012-11-06'}
# -----
# {'system_name': 'Bay Bucks', 'system_type': 'Bay Bucks\n\nMutual Credit System', 'system_origin': 'United States', 'system_serving': 'San Francisco Bay Area', 'establishment': '2012-11-01'}
# -----
# {'system_name': 'South Burnett LETS & Gympie LETS Exchange', 'system_type': 'South Burnett LETS & Gympie LETS Exchange\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'South Burnett & Gympie, Qld', 'establishment': '2012-10-20'}
# -----
# {'system_name': 'NITE Exchange (Global Accommodation)', 'system_type': 'NITE Exchange (Global Accommodation)\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'International', 'establishment': '2012-10-19'}
# -----
# {'system_name': 'Bay Bucks', 'system_type': 'Bay Bucks\n\nRobust Complementary Community Currency System', 'system_origin': 'United States', 'system_serving': 'Traverse City, MI', 'establishment': '2012-10-09'}
# -----
# {'system_name': 'Barter21', 'system_type': 'Barter21\n\nMerit Based Currency in Web Database', 'system_origin': 'Canada', 'system_serving': 'Nova Scotia', 'establishment': '2012-10-07'}
# -----
# {'system_name': 'ECO Alt Congost', 'system_type': 'ECO Alt Congost\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Spain', 'system_serving': 'Alt Congost, Catalunya', 'establishment': '2012-10-07'}
# -----
# {'system_name': '125', 'system_type': "125\n\nJardin d'Echange Universel", 'system_origin': 'United States', 'system_serving': 'Street', 'establishment': '2012-10-04'}
# -----
# {'system_name': 'A bona hora - Ecoxarxa del Bages', 'system_type': 'A bona hora - Ecoxarxa del Bages\n\nCommunity Exchange System', 'system_origin': 'Spain', 'system_serving': 'Bages', 'establishment': '2012-09-24'}
# -----
# {'system_name': 'The CollaborActions Network', 'system_type': 'The CollaborActions Network\n\nMutual Credit System', 'system_origin': 'United Kingdom', 'system_serving': 'Business Barter Scheme UK Wide', 'establishment': '2012-09-19'}
# -----
# {'system_name': 'Bridgetown Bucks', 'system_type': 'Bridgetown Bucks\n\nFiat Currency System', 'system_origin': 'United States', 'system_serving': 'Oregon', 'establishment': '2012-07-18'}
# -----
# {'system_name': 'le CIGALONDE', 'system_type': 'le CIGALONDE\n\nCommercial Exchange System', 'system_origin': 'France', 'system_serving': 'commerce local', 'establishment': '2012-04-09'}
# -----
# {'system_name': 'Humboldt Village Exchange', 'system_type': 'Humboldt Village Exchange\n\nCommunity Exchange System', 'system_origin': 'United States', 'system_serving': 'Humboldt Village', 'establishment': '2012-04-03'}
# -----
# {'system_name': 'The Baltimore BNote', 'system_type': 'The Baltimore BNote\n\nRobust Complementary Community Currency System', 'system_origin': 'United States', 'system_serving': 'Baltimore', 'establishment': '2012-03-10'}
# -----
# {'system_name': 'LETS Vlaanderen', 'system_type': 'LETS Vlaanderen\n\nLETSystem', 'system_origin': 'Belgium', 'system_serving': 'Vlaanderen', 'establishment': '2012-03-09'}
# -----
# {'system_name': 'PR-LETS', 'system_type': 'PR-LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Canada', 'system_serving': 'Powell River, BC', 'establishment': '2012-03-03'}
# -----
# {'system_name': 'RedeBarter - Moeda Complementar Local', 'system_type': 'RedeBarter - Moeda Complementar Local\n\nMultilateral Reciprocal Commerce - Local Currency', 'system_origin': 'Portugal', 'system_serving': 'Portugal', 'establishment': '2012-03-02'}
# -----
# {'system_name': 'Barter Angels', 'system_type': 'Barter Angels\n\nCommercial Exchange System', 'system_origin': 'United Kingdom', 'system_serving': 'Commercial', 'establishment': '2012-03-02'}
# -----
# {'system_name': 'Bendiu', 'system_type': 'Bendiu\n\nShared Balances System', 'system_origin': 'Italy', 'system_serving': 'Shardana', 'establishment': '2012-02-21'}
# -----
# {'system_name': 'Community Resources Center', 'system_type': 'Community Resources Center\n\nResources necessary for community resilience...', 'system_origin': 'Senegal', 'system_serving': 'Nationwide', 'establishment': '2012-02-18'}
# -----
# {'system_name': 'SELtique', 'system_type': 'SELtique\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Flémalle (Province de Liège)', 'establishment': '2012-02-12'}
# -----
# {'system_name': 'L.E.T.S.', 'system_type': 'L.E.T.S.\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Australia', 'system_serving': 'Western Australia', 'establishment': '2011-12-28'}
# -----
# {'system_name': 'Agate Pass Exchange', 'system_type': 'Agate Pass Exchange\n\nMutual Credit System', 'system_origin': 'United States', 'system_serving': 'North Kitsap County', 'establishment': '2011-12-18'}
# -----
# {'system_name': 'Villages', 'system_type': 'Villages\n\nRipple System', 'system_origin': 'Canada', 'system_serving': 'Global', 'establishment': '2011-11-12'}
# -----
# {'system_name': 'Mesure', 'system_type': 'Mesure\n\nMonnaie Locale Complémentaire (MLC)', 'system_origin': 'France', 'system_serving': 'Française', 'establishment': '2011-11-11'}
# -----
# {'system_name': 'Shire Silver', 'system_type': 'Shire Silver\n\nCommodity Based System', 'system_origin': 'United States', 'system_serving': 'World', 'establishment': '2011-11-07'}
# -----
# {'system_name': 'Freicoin', 'system_type': 'Freicoin\n\np2p cryptocurrency', 'system_origin': 'Spain', 'system_serving': 'Worldwide', 'establishment': '2011-10-05'}
# -----
# {'system_name': 'LETS', 'system_type': 'LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United States', 'system_serving': 'Chicagoland', 'establishment': '2011-09-30'}
# -----
# {'system_name': 'Swap', 'system_type': 'Swap\n\nMonnaie complémentaire virtuelle géolocalisée', 'system_origin': 'Switzerland', 'system_serving': 'Francophone', 'establishment': '2011-09-05'}
# -----
# {'system_name': 'RAMISEL', 'system_type': 'RAMISEL\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Wallone', 'establishment': '2011-08-19'}
# -----
# {'system_name': 'Brixton Pound', 'system_type': 'Brixton Pound\n\nCommunity Exchange System', 'system_origin': 'United Kingdom', 'system_serving': 'Brixton', 'establishment': '2011-08-18'}
# -----
# {'system_name': 'DKG - Deutsche Kompensationsgesellschaft mbH', 'system_type': 'DKG - Deutsche Kompensationsgesellschaft mbH\n\nCommercial Exchange System', 'system_origin': 'Germany', 'system_serving': 'Berlin', 'establishment': '2011-08-05'}
# -----
# {'system_name': 'SOL', 'system_type': "SOL\n\nSystème d'échange commercial + temps", 'system_origin': 'France', 'system_serving': 'mouvement national', 'establishment': '2011-07-27'}
# -----
# {'system_name': 'Open-Transactions', 'system_type': 'Open-Transactions\n\nTransaction Software', 'system_origin': 'United States', 'system_serving': 'Los Angeles', 'establishment': '2011-06-21'}
# -----
# {'system_name': 'KW Cash', 'system_type': 'KW Cash\n\nValuable Local Currency (VLC)', 'system_origin': 'United States', 'system_serving': 'Pennsylvania', 'establishment': '2011-06-14'}
# -----
# {'system_name': 'Ven', 'system_type': 'Ven\n\nGlobal financial currency', 'system_origin': 'Hong Kong', 'system_serving': 'Worldwide', 'establishment': '2011-06-08'}
# -----
# {'system_name': 'Bitcoin', 'system_type': 'Bitcoin\n\np2p cryptocurrency', 'system_origin': 'United States', 'system_serving': 'Worldwide', 'establishment': '2011-05-11'}
# -----
# {'system_name': 'Ripplepay', 'system_type': 'Ripplepay\n\nRipple System', 'system_origin': 'Canada', 'system_serving': 'Global', 'establishment': '2011-05-09'}
# -----
# {'system_name': 'Rain Droplet', 'system_type': 'Rain Droplet\n\nMutual Credit System', 'system_origin': 'Canada', 'system_serving': 'Several', 'establishment': '2011-05-07'}
# -----
# {'system_name': 'Realo', 'system_type': 'Realo\n\nCommunity Barter System', 'system_origin': 'Germany', 'system_serving': 'ReWiG Tauschgemeinschaft', 'establishment': '2011-04-30'}
# -----
# {'system_name': 'Eko', 'system_type': 'Eko\n\nValuable Local Currency (VLC)', 'system_origin': 'Scotland', 'system_serving': 'Findhorn Ecovillage', 'establishment': '2011-04-12'}
# -----
# {'system_name': 'Time Bank Dobrobank', 'system_type': 'Time Bank Dobrobank\n\nTime Bank System', 'system_origin': 'Ukraine', 'system_serving': 'Ukrainian Public Organization', 'establishment': '2011-04-09'}
# -----
# {'system_name': 'SELEsneux', 'system_type': 'SELEsneux\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Wallonie', 'establishment': '2011-04-08'}
# -----
# {'system_name': 'Augusta', 'system_type': 'Augusta\n\nGogo System', 'system_origin': 'Germany', 'system_serving': 'Göttingen', 'establishment': '2011-04-06'}
# -----
# {'system_name': 'Unis-Vers-Sel', 'system_type': 'Unis-Vers-Sel\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Wallonie', 'establishment': '2011-04-04'}
# -----
# {'system_name': 'SEL de Somme', 'system_type': 'SEL de Somme\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Française', 'establishment': '2011-03-14'}
# -----
# {'system_name': 'Clés de SEL', 'system_type': 'Clés de SEL\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Wallonie', 'establishment': '2011-03-14'}
# -----
# {'system_name': 'Dane County TimeBank', 'system_type': 'Dane County TimeBank\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Dane County', 'establishment': '2011-02-16'}
# -----
# {'system_name': 'Banco de Tiempo de Belén', 'system_type': 'Banco de Tiempo de Belén\n\nTime Bank System', 'system_origin': 'Colombia', 'system_serving': 'Estratos medio y bajo', 'establishment': '2011-01-21'}
# -----
# {'system_name': 'Kékfrank', 'system_type': 'Kékfrank\n\nVoucher Currency System', 'system_origin': 'Hungary', 'system_serving': 'Region Sopron', 'establishment': '2011-01-04'}
# -----
# {'system_name': 'Bakonyi CsereKÖR', 'system_type': 'Bakonyi CsereKÖR', 'system_origin': 'Hungary', 'system_serving': 'Bakonyi CsereKÖR', 'establishment': '2011-01-03'}
# -----
# {'system_name': 'SEL Glânois & Alentours', 'system_type': 'SEL Glânois & Alentours\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Switzerland', 'system_serving': 'Glâne', 'establishment': '2010-12-19'}
# -----
# {'system_name': 'Sistema de Trueke Kirikire de Los Valles del Tuy', 'system_type': 'Sistema de Trueke Kirikire de Los Valles del Tuy\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Región Valles del Tuy (estado Miranda)', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Merideño', 'system_type': 'Sistema de Trueke Merideño\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Estado Mérida', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Saquito Larense', 'system_type': 'Sistema de Trueke Saquito Larense\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Sanare, Quibor, El Tocuyo, Barquisimeto (edo Lara)', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Cimarrón de Barlovento', 'system_type': 'Sistema de Trueke Cimarrón de Barlovento\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Región Barlovento (estado Miranda)', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Perijá Sur', 'system_type': 'Sistema de Trueke Perijá Sur\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Machiques de Perijá (estado Zulia)', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Perijá Norte', 'system_type': 'Sistema de Trueke Perijá Norte\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Villa del Rosario de Perijá', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Bio-Región Turimiquire', 'system_type': 'Sistema de Trueke Bio-Región Turimiquire\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Sierra de Turimiquire', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke Ticoporo', 'system_type': 'Sistema de Trueke Ticoporo\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Estado Barinas', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke de l@s Pariagotos', 'system_type': 'Sistema de Trueke de l@s Pariagotos\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Península de Paria', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke de Paraguachoa', 'system_type': 'Sistema de Trueke de Paraguachoa\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Isla Margarita', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke de Boconó', 'system_type': 'Sistema de Trueke de Boconó\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Boconó', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke de la C.C.C. José L Chirinos', 'system_type': 'Sistema de Trueke de la C.C.C. José L Chirinos\n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'Confederación de Consjs Comunales José L. Chirin', 'establishment': '2010-12-11'}
# -----
# {'system_name': 'Sistema de Trueke de Urachiche', 'system_type': 'Sistema de Trueke de Urachiche \n\nSistema de Trueke', 'system_origin': 'Venezuela', 'system_serving': 'municipio Urachiche, Yaracuy', 'establishment': '2010-11-02'}
# -----
# {'system_name': 'Hour Exchange Portland', 'system_type': 'Hour Exchange Portland\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Greater Portland, Maine', 'establishment': '2010-08-30'}
# -----
# {'system_name': 'Otaki Time Bank', 'system_type': 'Otaki Time Bank\n\nTime Bank System', 'system_origin': 'New Zealand', 'system_serving': 'Otaki', 'establishment': '2010-07-26'}
# -----
# {'system_name': '1worldcurrency.net', 'system_type': '1worldcurrency.net\n\nInterest free resource based electronic', 'system_origin': 'United States', 'system_serving': 'Planet Earth', 'establishment': '2010-07-14'}
# -----
# {'system_name': 'Málaga Común', 'system_type': 'Málaga Común\n\nLETSystem', 'system_origin': 'Spain', 'system_serving': 'Málaga', 'establishment': '2010-06-16'}
# -----
# {'system_name': 'Premier Barter', 'system_type': 'Premier Barter\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United States', 'system_serving': 'Phoenix, AZ', 'establishment': '2010-06-04'}
# -----
# {'system_name': 'MittelFranken', 'system_type': 'MittelFranken\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Schwabach', 'establishment': '2010-05-24'}
# -----
# {'system_name': 'Regional Exchange System', 'system_type': 'Regional Exchange System\n\nRobust Complementary Community Currency System', 'system_origin': 'Ukraine', 'system_serving': 'International', 'establishment': '2010-05-21'}
# -----
# {'system_name': 'SEL de MARS', 'system_type': 'SEL de MARS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'France', 'system_serving': 'SEL de MARS', 'establishment': '2010-05-05'}
# -----
# {'system_name': 'monsSEL', 'system_type': 'monsSEL\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'locale', 'establishment': '2010-04-25'}
# -----
# {'system_name': 'TWINZ', 'system_type': 'TWINZ\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'New Zealand', 'system_serving': 'Nelson', 'establishment': '2010-04-07'}
# -----
# {'system_name': 'SELeri', 'system_type': 'SELeri\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Rixensart', 'establishment': '2010-03-11'}
# -----
# {'system_name': 'Macasel', 'system_type': 'Macasel\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Wallonie', 'establishment': '2010-03-10'}
# -----
# {'system_name': "SEL'Bonheur Beauvechain", 'system_type': "SEL'Bonheur Beauvechain\n\nLocal Exchange Trading System  (LETS)", 'system_origin': 'Belgium', 'system_serving': 'Brabant Wallon', 'establishment': '2010-03-10'}
# -----
# {'system_name': 'Dreyecker', 'system_type': 'Dreyecker\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Schopfheim', 'establishment': '2010-02-24'}
# -----
# {'system_name': 'Minuto-ZeitGutscheine', 'system_type': 'Minuto-ZeitGutscheine\n\nIndividual-Emissionssystem', 'system_origin': 'Germany', 'system_serving': 'International', 'establishment': '2010-02-23'}
# -----
# {'system_name': 'South East Wales LETS', 'system_type': 'South East Wales LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United Kingdom', 'system_serving': 'South East Wales', 'establishment': '2010-02-17'}
# -----
# {'system_name': 'RiverHOURS', 'system_type': 'RiverHOURS\n\nHOURS System', 'system_origin': 'United States', 'system_serving': 'Columbia River Gorge', 'establishment': '2009-11-04'}
# -----
# {'system_name': 'Unity Currency', 'system_type': 'Unity Currency\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United States', 'system_serving': 'International', 'establishment': '2009-11-03'}
# -----
# {'system_name': 'Milwaukee Area Time Exchange', 'system_type': 'Milwaukee Area Time Exchange\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Milwaukee County', 'establishment': '2009-10-07'}
# -----
# {'system_name': 'Falmouth LETS', 'system_type': 'Falmouth LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United Kingdom', 'system_serving': 'Falmouth (10 mile radius)', 'establishment': '2009-09-04'}
# -----
# {'system_name': 'Bay Of Islands Community Exchange', 'system_type': 'Bay Of Islands Community Exchange\n\nCommunity Exchange System', 'system_origin': 'New Zealand', 'system_serving': 'Bay Of Islands', 'establishment': '2009-08-11'}
# -----
# {'system_name': 'Eastern Suburbs / Warranwood LETS Live Inc.', 'system_type': 'Eastern Suburbs / Warranwood LETS Live Inc.\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Australia', 'system_serving': 'Melbourne', 'establishment': '2009-08-07'}
# -----
# {'system_name': 'Totnes Pound', 'system_type': 'Totnes Pound\n\nCommunity Exchange System', 'system_origin': 'United Kingdom', 'system_serving': 'Totnes', 'establishment': '2009-07-24'}
# -----
# {'system_name': 'Ann Arbor Small Business & Community Exchange', 'system_type': 'Ann Arbor Small Business & Community Exchange\n\nLETSystem', 'system_origin': 'United States', 'system_serving': 'Ann Arbor - Washtenaw County', 'establishment': '2009-07-17'}
# -----
# {'system_name': 'TATS', 'system_type': 'TATS\n\nCommunity Exchange System', 'system_origin': 'New Zealand', 'system_serving': 'South Canterbury', 'establishment': '2009-07-10'}
# -----
# {'system_name': 'TALENTS', 'system_type': 'TALENTS\n\nCommunity Exchange System', 'system_origin': 'New Zealand', 'system_serving': 'Motueka', 'establishment': '2009-07-09'}
# -----
# {'system_name': 'BarterWorks', 'system_type': 'BarterWorks\n\nLETSystem', 'system_origin': 'Canada', 'system_serving': 'Kitchener', 'establishment': '2009-07-09'}
# -----
# {'system_name': 'Time Bank', 'system_type': 'Time Bank\n\nTime Bank System', 'system_origin': 'New Zealand', 'system_serving': 'Lyttelton', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'Byron Shire Community Exchange', 'system_type': 'Byron Shire Community Exchange\n\nLETSystem', 'system_origin': 'Australia', 'system_serving': 'Byron Shire', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'Wellington Talent Exchange', 'system_type': 'Wellington Talent Exchange\n\nCommunity Exchange System', 'system_origin': 'New Zealand', 'system_serving': 'Wellington Region', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'St. Louis Community Exchange', 'system_type': 'St. Louis Community Exchange\n\nCommercial Exchange System', 'system_origin': 'United States', 'system_serving': 'Saint Louis, Missouri', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'Shoalhaven Community Exchange', 'system_type': 'Shoalhaven Community Exchange\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'Shoalhaven', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'Johannesburg Talent Exchange', 'system_type': 'Johannesburg Talent Exchange\n\nCommunity Exchange System', 'system_origin': 'South Africa', 'system_serving': 'Johannesburg', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'Kingston Bayside LETS', 'system_type': 'Kingston Bayside LETS\n\nLETSystem', 'system_origin': 'Australia', 'system_serving': 'Melbourne', 'establishment': '2009-07-08'}
# -----
# {'system_name': 'Merit Exchange', 'system_type': 'Merit Exchange\n\nMerit Based Currency in Web Database', 'system_origin': 'United States', 'system_serving': 'National', 'establishment': '2009-07-02'}
# -----
# {'system_name': 'SEL de MARS\\\\\\\\', 'system_type': 'SEL de MARS\\\\\\\\\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'France', 'system_serving': 'SEL', 'establishment': '2009-06-08'}
# -----
# {'system_name': 'La Route des SEL', 'system_type': 'La Route des SEL\n\nNuités = unités temps / nights = times units', 'system_origin': 'France', 'system_serving': '177 rue Pierre Loti', 'establishment': '2009-05-11'}
# -----
# {'system_name': 'SEL\\\\', 'system_type': 'SEL\\\\\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'France', 'system_serving': 'BP 60034', 'establishment': '2009-05-09'}
# -----
# {'system_name': 'Talente Tauschkreis Vorarlberg TTKV', 'system_type': 'Talente Tauschkreis Vorarlberg TTKV\n\nRegionale Komplementärwährung', 'system_origin': 'Austria', 'system_serving': 'Vorarlberg', 'establishment': '2009-04-24'}
# -----
# {'system_name': 'Cape Town Talent Exchange', 'system_type': 'Cape Town Talent Exchange\n\nCommunity Exchange System', 'system_origin': 'South Africa', 'system_serving': 'Cape Town', 'establishment': '2009-04-01'}
# -----
# {'system_name': 'GibundNimm-Forum', 'system_type': 'GibundNimm-Forum\n\nMutual Credit System', 'system_origin': 'Germany', 'system_serving': 'Baden-Württemberg', 'establishment': '2009-04-01'}
# -----
# {'system_name': 'Baroon Dollar', 'system_type': 'Baroon Dollar\n\nVoucher Currency System', 'system_origin': 'Australia', 'system_serving': 'Hinterland, Sunshine Coast', 'establishment': '2009-03-23'}
# -----
# {'system_name': 'AOCS Approved', 'system_type': 'AOCS Approved\n\nAmerican Open Currency Standard', 'system_origin': 'United States', 'system_serving': 'National', 'establishment': '2009-03-23'}
# -----
# {'system_name': 'SELAtlas', 'system_type': "SELAtlas\n\nSystème d'échange local LETS/SEL", 'system_origin': 'Belgium', 'system_serving': 'Anderlecht', 'establishment': '2009-02-28'}
# -----
# {'system_name': 'CREES', 'system_type': 'CREES\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'Caboolture', 'establishment': '2009-02-10'}
# -----
# {'system_name': 'PITNIO', 'system_type': 'PITNIO\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Greece', 'system_serving': 'Ierapetra', 'establishment': '2009-02-06'}
# -----
# {'system_name': 'Time Bank of Ierapetra', 'system_type': 'Time Bank of Ierapetra\n\nTime Bank System', 'system_origin': 'Greece', 'system_serving': 'Ierapetra', 'establishment': '2009-02-06'}
# -----
# {'system_name': 'exchange*me', 'system_type': 'exchange*me\n\nMarketplace Currency (ie. RGT)', 'system_origin': 'Germany', 'system_serving': 'Deutschland', 'establishment': '2009-01-26'}
# -----
# {'system_name': 'OVOLOS CC', 'system_type': 'OVOLOS CC\n\nLETSystem', 'system_origin': 'Greece', 'system_serving': 'GREECE', 'establishment': '2009-01-02'}
# -----
# {'system_name': 'The Maia Maia Project', 'system_type': 'The Maia Maia Project\n\nGreenhouse Gas Reduction / Carbon Credits', 'system_origin': 'Australia', 'system_serving': 'Perth', 'establishment': '2008-12-31'}
# -----
# {'system_name': 'Proyecto Mutuo', 'system_type': 'Proyecto Mutuo\n\nMutual Credit System', 'system_origin': 'Argentina', 'system_serving': 'Martínez', 'establishment': '2008-12-26'}
# -----
# {'system_name': 'Diamond Valley/Northern Suburbs LETS inc.', 'system_type': 'Diamond Valley/Northern Suburbs LETS inc.\n\nLETSystem', 'system_origin': 'Australia', 'system_serving': 'general public', 'establishment': '2008-10-20'}
# -----
# {'system_name': 'Adelaide LETS', 'system_type': 'Adelaide LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Australia', 'system_serving': 'Windsor Gardens', 'establishment': '2008-10-17'}
# -----
# {'system_name': 'Moreland LETS', 'system_type': 'Moreland LETS\n\nLETSystem', 'system_origin': 'Australia', 'system_serving': 'Moreland', 'establishment': '2008-10-16'}
# -----
# {'system_name': 'Charity Exchange Shop', 'system_type': 'Charity Exchange Shop\n\nLETSystem', 'system_origin': 'Hungary', 'system_serving': 'Szolnok', 'establishment': '2008-10-08'}
# -----
# {'system_name': 'EBB Barter', 'system_type': 'EBB Barter\n\nCommercial Exchange System', 'system_origin': 'Germany', 'system_serving': 'Arges', 'establishment': '2008-10-08'}
# -----
# {'system_name': 'bizunlimited', 'system_type': 'bizunlimited\n\nCommercial Exchange System', 'system_origin': 'United Kingdom', 'system_serving': 'SMEs', 'establishment': '2008-09-11'}
# -----
# {'system_name': 'Crom Alternative Exchange', 'system_type': 'Crom Alternative Exchange\n\nCrom Alternative Exchange System', 'system_origin': 'Croatia', 'system_serving': 'The whole wide World', 'establishment': '2008-09-02'}
# -----
# {'system_name': 'DiBuck', 'system_type': 'DiBuck\n\nFiat Currency System', 'system_origin': 'United Kingdom', 'system_serving': 'Internet', 'establishment': '2008-08-13'}
# -----
# {'system_name': 'LETS Antwerpen Stad', 'system_type': 'LETS Antwerpen Stad\n\nLETSystem', 'system_origin': 'Belgium', 'system_serving': 'Antwerpen Stad', 'establishment': '2008-07-09'}
# -----
# {'system_name': 'DANEE', 'system_type': 'DANEE\n\nFiat Currency System', 'system_origin': 'Italy', 'system_serving': 'MILANESE', 'establishment': '2008-06-30'}
# -----
# {'system_name': 'BrisLETS', 'system_type': 'BrisLETS\n\nLETSystem', 'system_origin': 'Australia', 'system_serving': 'Brisbane', 'establishment': '2008-06-23'}
# -----
# {'system_name': 'Wairarapa Green Dollar Exchange', 'system_type': 'Wairarapa Green Dollar Exchange\n\nLETSystem', 'system_origin': 'New Zealand', 'system_serving': 'Wairarapa', 'establishment': '2008-05-24'}
# -----
# {'system_name': 'Central Coast LETS', 'system_type': 'Central Coast LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Australia', 'system_serving': 'Central Coast of NSW', 'establishment': '2008-05-21'}
# -----
# {'system_name': 'Qoin', 'system_type': 'Qoin\n\nCommercial Exchange System', 'system_origin': 'Netherlands', 'system_serving': 'Bedrijven', 'establishment': '2008-04-28'}
# -----
# {'system_name': 'SCEC', 'system_type': 'SCEC\n\nFiat Currency System', 'system_origin': 'Italy', 'system_serving': 'Progetto SCEC', 'establishment': '2007-12-27'}
# -----
# {'system_name': 'absi', 'system_type': 'absi\n\nMutual Credit Hybrid', 'system_origin': 'Denmark', 'system_serving': 'Yes', 'establishment': '2007-12-17'}
# -----
# {'system_name': 'Waldo County Community Exchange', 'system_type': 'Waldo County Community Exchange\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Waldo county, Maine', 'establishment': '2007-12-09'}
# -----
# {'system_name': 'Bega Valley LETS', 'system_type': 'Bega Valley LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Australia', 'system_serving': 'Sth East NSW', 'establishment': '2007-12-06'}
# -----
# {'system_name': 'Pagadoo Loyalty System', 'system_type': 'Pagadoo Loyalty System\n\nCredit Card Based Exchange System with Web access', 'system_origin': 'Spain', 'system_serving': 'All communities', 'establishment': '2007-11-26'}
# -----
# {'system_name': 'Tikiwiki + CC Mod', 'system_type': 'Tikiwiki + CC Mod\n\nTransaction Software', 'system_origin': 'Spain', 'system_serving': 'XAINGRA', 'establishment': '2007-11-22'}
# -----
# {'system_name': 'Letsbuzz', 'system_type': 'Letsbuzz\n\nLETSystem', 'system_origin': 'United Kingdom', 'system_serving': 'Leighton Buzzard area', 'establishment': '2007-11-22'}
# -----
# {'system_name': 'Swan Hills LETS', 'system_type': 'Swan Hills LETS\n\nLETSystem', 'system_origin': 'Australia', 'system_serving': 'Perth Hills Region', 'establishment': '2007-10-31'}
# -----
# {'system_name': 'Bricioline', 'system_type': 'Bricioline\n\nMutual Credit Hybrid', 'system_origin': 'Italy', 'system_serving': 'Italy', 'establishment': '2007-10-18'}
# -----
# {'system_name': 'LETS den Haag', 'system_type': 'LETS den Haag\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Netherlands', 'system_serving': 'Den Haag', 'establishment': '2007-10-13'}
# -----
# {'system_name': 'Common Goods', 'system_type': 'Common Goods\n\nCommon Good Credit System', 'system_origin': 'United States', 'system_serving': 'Western Franklin County Massachusetts', 'establishment': '2007-09-19'}
# -----
# {'system_name': 'North Quabin Timebank', 'system_type': 'North Quabin Timebank\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Central Massachusetts', 'establishment': '2007-09-12'}
# -----
# {'system_name': 'TradeMarket', 'system_type': 'TradeMarket\n\nMutual Credit System', 'system_origin': 'United States', 'system_serving': 'Nevada City / Grass Valley', 'establishment': '2007-09-08'}
# -----
# {'system_name': 'NDG Barter Network', 'system_type': 'NDG Barter Network\n\nLETSystem', 'system_origin': 'Canada', 'system_serving': 'NDG (Notre Dame de Grace)', 'establishment': '2007-08-11'}
# -----
# {'system_name': 'EBB-Euro Barter Business', 'system_type': 'EBB-Euro Barter Business\n\nCommercial Exchange System', 'system_origin': 'Germany', 'system_serving': 'Rheinmünster', 'establishment': '2007-04-22'}
# -----
# {'system_name': 'CES Montreal', 'system_type': 'CES Montreal\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Canada', 'system_serving': 'Montreal', 'establishment': '2007-04-16'}
# -----
# {'system_name': 'Coinsystem', 'system_type': 'Coinsystem\n\nCommercial Exchange System', 'system_origin': 'Germany', 'system_serving': 'Nordrhein-Westfalen', 'establishment': '2007-04-13'}
# -----
# {'system_name': 'OSCurrency', 'system_type': 'OSCurrency\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United States', 'system_serving': 'Austin Metro', 'establishment': '2007-04-12'}
# -----
# {'system_name': 'LA21-Jugendprojekt I-MOTION', 'system_type': 'LA21-Jugendprojekt I-MOTION\n\nVoucher Currency System', 'system_origin': 'Austria', 'system_serving': 'Wörgl', 'establishment': '2007-03-16'}
# -----
# {'system_name': 'BruSEL', 'system_type': 'BruSEL\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Belgium', 'system_serving': 'Bruxelles', 'establishment': '2007-03-14'}
# -----
# {'system_name': 'Ithaca HOURS', 'system_type': 'Ithaca HOURS\n\nHOURS System', 'system_origin': 'United States', 'system_serving': 'Ithaca, New York', 'establishment': '2006-11-29'}
# -----
# {'system_name': 'Scunnymoney', 'system_type': 'Scunnymoney\n\nFiat Currency System', 'system_origin': 'United Kingdom', 'system_serving': 'Scunthorpe', 'establishment': '2006-11-13'}
# -----
# {'system_name': 'BerkShares, Inc.', 'system_type': 'BerkShares, Inc.\n\nVoucher Currency System', 'system_origin': 'United States', 'system_serving': 'berkshires', 'establishment': '2006-11-13'}
# -----
# {'system_name': 'NOCO Hours', 'system_type': 'NOCO Hours\n\nHOURS System', 'system_origin': 'United States', 'system_serving': 'Fort Collins', 'establishment': '2006-11-04'}
# -----
# {'system_name': 'Solidário', 'system_type': 'Solidário\n\nCommunity Barter System', 'system_origin': 'Portugal', 'system_serving': 'São Brás de Alportel', 'establishment': '2006-10-22'}
# -----
# {'system_name': 'Die Oderblüte', 'system_type': 'Die Oderblüte\n\nMutual Credit System', 'system_origin': 'Germany', 'system_serving': 'LK Barnim u. Uckermark', 'establishment': '2006-10-11'}
# -----
# {'system_name': 'Bath LETS', 'system_type': 'Bath LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United Kingdom', 'system_serving': 'Bath', 'establishment': '2006-10-05'}
# -----
# {'system_name': 'Wageningen-LETS', 'system_type': 'Wageningen-LETS\n\nLETSystem', 'system_origin': 'Netherlands', 'system_serving': 'Wageningen, Renkum, Ede', 'establishment': '2006-09-25'}
# -----
# {'system_name': 'Kupon Merapi Mulia', 'system_type': 'Kupon Merapi Mulia\n\nVoucher Currency System', 'system_origin': 'Indonesia', 'system_serving': 'Daleman Village, Turi, Sleman', 'establishment': '2006-08-27'}
# -----
# {'system_name': 'Por System', 'system_type': 'Por System\n\nVoucher Currency System', 'system_origin': 'Thailand', 'system_serving': 'Pawa Ampur Kang Hang Maew', 'establishment': '2006-06-06'}
# -----
# {'system_name': 'Boon Kud Chum', 'system_type': 'Boon Kud Chum\n\nMutual Credit System', 'system_origin': 'Thailand', 'system_serving': 'Satisuk Ampur Kud Chum', 'establishment': '2006-06-06'}
# -----
# {'system_name': 'Jai System', 'system_type': 'Jai System\n\nVoucher Currency System', 'system_origin': 'Thailand', 'system_serving': 'Non Taklang Ampur Nonsoong', 'establishment': '2006-06-06'}
# -----
# {'system_name': 'Tiroler Stunde', 'system_type': 'Tiroler Stunde\n\nCommunity Way', 'system_origin': 'Austria', 'system_serving': 'Tirol', 'establishment': '2006-06-02'}
# -----
# {'system_name': 'Urstromtaler', 'system_type': 'Urstromtaler\n\nMutual Credit System', 'system_origin': 'Germany', 'system_serving': 'Magdeburg', 'establishment': '2006-05-03'}
# -----
# {'system_name': 'Rössle', 'system_type': 'Rössle\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Stuttgart', 'establishment': '2006-04-11'}
# -----
# {'system_name': 'ナマケ', 'system_type': 'ナマケ\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Japan', 'system_serving': '日本', 'establishment': '2006-04-05'}
# -----
# {'system_name': 'Invercargill Barter & Exchange Systems', 'system_type': 'Invercargill Barter & Exchange Systems\n\nCommunity Barter System', 'system_origin': 'New Zealand', 'system_serving': 'Southland', 'establishment': '2006-03-14'}
# -----
# {'system_name': 'Maleny LETS', 'system_type': 'Maleny LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Australia', 'system_serving': 'Maleny', 'establishment': '2006-03-06'}
# -----
# {'system_name': 'Sydney and Illawarra LETS', 'system_type': 'Sydney and Illawarra LETS\n\nCommunity Exchange System', 'system_origin': 'Australia', 'system_serving': 'Sydney', 'establishment': '2006-03-05'}
# -----
# {'system_name': 'Brod€inheit', 'system_type': 'Brod€inheit\n\nCommunity Barter System', 'system_origin': 'Germany', 'system_serving': 'Altenkirchen', 'establishment': '2006-03-05'}
# -----
# {'system_name': 'Cooperativa de Trueque Almatroque', 'system_type': 'Cooperativa de Trueque Almatroque\n\nMutual Credit System', 'system_origin': 'Spain', 'system_serving': 'Alicante', 'establishment': '2006-02-13'}
# -----
# {'system_name': 'VolmeTALER', 'system_type': 'VolmeTALER\n\nVoucher Currency System', 'system_origin': 'Germany', 'system_serving': 'Hagen', 'establishment': '2006-02-08'}
# -----
# {'system_name': 'DreyEcker', 'system_type': 'DreyEcker\n\nVoucher Currency System', 'system_origin': 'Germany', 'system_serving': '79650 Schopfheim', 'establishment': '2006-02-08'}
# -----
# {'system_name': 'TAUBER-FRANKEN e.V.', 'system_type': 'TAUBER-FRANKEN e.V.\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Creglingen', 'establishment': '2006-02-07'}
# -----
# {'system_name': 'Proyecto Trueke', 'system_type': 'Proyecto Trueke\n\nMarketplace Currency (ie. RGT)', 'system_origin': 'Colombia', 'system_serving': 'Pajarito', 'establishment': '2006-02-07'}
# -----
# {'system_name': 'Hansemark', 'system_type': 'Hansemark\n\nGogo System', 'system_origin': 'Germany', 'system_serving': 'Hamburg', 'establishment': '2006-02-07'}
# -----
# {'system_name': 'Havelbluete', 'system_type': 'Havelbluete\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Land Brandenburg', 'establishment': '2006-02-07'}
# -----
# {'system_name': 'Lausitzer', 'system_type': 'Lausitzer\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Region Lausitz', 'establishment': '2006-02-07'}
# -----
# {'system_name': 'Lets Boemerang', 'system_type': 'Lets Boemerang\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Netherlands', 'system_serving': 'Gouda e.o.', 'establishment': '2006-01-26'}
# -----
# {'system_name': 'Chiemgauer', 'system_type': 'Chiemgauer\n\nVoucher Currency System', 'system_origin': 'Germany', 'system_serving': 'Prien', 'establishment': '2006-01-25'}
# -----
# {'system_name': 'Barter System Poland', 'system_type': 'Barter System Poland\n\nCommercial Exchange System', 'system_origin': 'Poland', 'system_serving': 'Poland', 'establishment': '2006-01-23'}
# -----
# {'system_name': 'LETS Studnicka', 'system_type': 'LETS Studnicka\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Slovakia', 'system_serving': 'Bratislava', 'establishment': '2006-01-20'}
# -----
# {'system_name': 'Tianguis Tlaloc', 'system_type': 'Tianguis Tlaloc\n\nMutual Credit Hybrid', 'system_origin': 'Mexico', 'system_serving': 'Colonia Tlaxpana', 'establishment': '2006-01-12'}
# -----
# {'system_name': 'CCD - Canterbury Community Dollars Exchange Inc.', 'system_type': 'CCD - Canterbury Community Dollars Exchange Inc.\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'New Zealand', 'system_serving': 'Christchurch', 'establishment': '2006-01-11'}
# -----
# {'system_name': 'Lokale Ruilkring', 'system_type': 'Lokale Ruilkring\n\nMutual Credit System', 'system_origin': 'Netherlands', 'system_serving': 'Unknown', 'establishment': '2006-01-10'}
# -----
# {'system_name': 'RES - Hét andere Geld!', 'system_type': 'RES - Hét andere Geld!\n\nValuable Local Currency (VLC)', 'system_origin': 'Belgium', 'system_serving': 'JA', 'establishment': '2006-01-09'}
# -----
# {'system_name': 'Community Eco-Village 社區經濟村計劃', 'system_type': 'Community Eco-Village 社區經濟村計劃\n\nTime Dollar System', 'system_origin': 'China', 'system_serving': 'Shatin, Hong Kong', 'establishment': '2006-01-09'}
# -----
# {'system_name': 'Stichting LETS Tiel', 'system_type': 'Stichting LETS Tiel\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Netherlands', 'system_serving': 'Tiel', 'establishment': '2006-01-04'}
# -----
# {'system_name': 'Talente Tauschring Hannover', 'system_type': 'Talente Tauschring Hannover\n\nMutual Credit System', 'system_origin': 'Germany', 'system_serving': 'Hannover', 'establishment': '2006-01-03'}
# -----
# {'system_name': 'OORD', 'system_type': 'OORD\n\nMutual Credit System', 'system_origin': 'Netherlands', 'system_serving': 'OORD', 'establishment': '2005-12-21'}
# -----
# {'system_name': 'Victoria Local Exchange Trading System', 'system_type': 'Victoria Local Exchange Trading System\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Canada', 'system_serving': 'Victoria, British Columbia', 'establishment': '2005-12-20'}
# -----
# {'system_name': 'stichting LETS Utrecht e.o., het Sterrenstelsel', 'system_type': 'stichting LETS Utrecht e.o., het Sterrenstelsel\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Netherlands', 'system_serving': 'Utrecht', 'establishment': '2005-12-20'}
# -----
# {'system_name': 'Circle of Gifts', 'system_type': 'Circle of Gifts\n\nCommunity Barter System', 'system_origin': 'Sweden', 'system_serving': 'Internet users', 'establishment': '2005-12-20'}
# -----
# {'system_name': 'Time Banks USA', 'system_type': 'Time Banks USA\n\nTime Bank System', 'system_origin': 'United States', 'system_serving': 'Maine', 'establishment': '2005-12-19'}
# -----
# {'system_name': 'Philadelphia and Boston HOURS', 'system_type': 'Philadelphia and Boston HOURS\n\nHOURS System', 'system_origin': 'United States', 'system_serving': 'Philadelphia and Boston', 'establishment': '2005-12-13'}
# -----
# {'system_name': 'Burlington Currency Project (Bread)', 'system_type': 'Burlington Currency Project (Bread)\n\nMutual Credit Hybrid', 'system_origin': 'United States', 'system_serving': 'Burlington', 'establishment': '2005-12-13'}
# -----
# {'system_name': 'Mutirão Quilombo da Serra', 'system_type': 'Mutirão Quilombo da Serra\n\nMarketplace Currency (ie. RGT)', 'system_origin': 'Brazil', 'system_serving': 'Poço do Peixe', 'establishment': '2005-11-05'}
# -----
# {'system_name': 'Earth Day Money', 'system_type': 'Earth Day Money\n\nCommunity Way', 'system_origin': 'Japan', 'system_serving': 'Shibuya', 'establishment': '2005-10-22'}
# -----
# {'system_name': 'unknown', 'system_type': 'unknown\n\nCommunity Barter System', 'system_origin': 'Japan', 'system_serving': 'unknown', 'establishment': '2005-10-13'}
# -----
# {'system_name': 'HALLERTAUER', 'system_type': 'HALLERTAUER\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': '85276 Pfaffenhofen', 'establishment': '2005-09-27'}
# -----
# {'system_name': 'VLC Porto Alegre', 'system_type': 'VLC Porto Alegre\n\nValuable Local Currency (VLC)', 'system_origin': 'Brazil', 'system_serving': 'Rio Grande do Sul', 'establishment': '2005-09-15'}
# -----
# {'system_name': 'C3 Mais Tobias', 'system_type': 'C3 Mais Tobias\n\nConsumer Commerce Circuit (C3)', 'system_origin': 'Brazil', 'system_serving': 'Sergipe', 'establishment': '2005-09-15'}
# -----
# {'system_name': 'C3 CompRaS', 'system_type': 'C3 CompRaS\n\nConsumer Commerce Circuit (C3)', 'system_origin': 'Brazil', 'system_serving': 'Rio Grande do Sul', 'establishment': '2005-09-15'}
# -----
# {'system_name': 'C3 Paraná', 'system_type': 'C3 Paraná\n\nConsumer Commerce Circuit (C3)', 'system_origin': 'Brazil', 'system_serving': 'Paraná', 'establishment': '2005-09-15'}
# -----
# {'system_name': 'Toronto Dollars', 'system_type': 'Toronto Dollars\n\nVoucher Currency System', 'system_origin': 'Canada', 'system_serving': 'Toronto', 'establishment': '2005-08-18'}
# -----
# {'system_name': 'Hanbat LETS', 'system_type': 'Hanbat LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'South Korea', 'system_serving': 'Hanbat LETS', 'establishment': '2005-08-09'}
# -----
# {'system_name': 'New Moray LETS', 'system_type': 'New Moray LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'United Kingdom', 'system_serving': 'Moray', 'establishment': '2005-07-30'}
# -----
# {'system_name': 'Fourth Corner Exchange', 'system_type': 'Fourth Corner Exchange\n\nCommunity Cooperation System', 'system_origin': 'United States', 'system_serving': 'Pacific Northwest', 'establishment': '2005-07-29'}
# -----
# {'system_name': 'Rheingold', 'system_type': 'Rheingold\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Düsseldorf', 'establishment': '2005-07-29'}
# -----
# {'system_name': 'Salt Spring Dollars', 'system_type': 'Salt Spring Dollars\n\nVoucher Currency System', 'system_origin': 'Canada', 'system_serving': 'Salt Spring Island', 'establishment': '2005-07-28'}
# -----
# {'system_name': 'にほうコミュニティ交換システム', 'system_type': 'にほうコミュニティ交換システム\n\nMutual Credit System', 'system_origin': 'Japan', 'system_serving': '福岡・大分県境の山国川河口地域', 'establishment': '2005-07-28'}
# -----
# {'system_name': 'NOPPES', 'system_type': 'NOPPES\n\nMutual Credit System', 'system_origin': 'Netherlands', 'system_serving': 'Amsterdam', 'establishment': '2005-07-21'}
# -----
# {'system_name': 'Landmark', 'system_type': 'Landmark\n\nREGIO System', 'system_origin': 'Germany', 'system_serving': 'Reinstädt', 'establishment': '2005-07-21'}
# -----
# {'system_name': 'fm(future money)', 'system_type': 'fm(future money)\n\nMutual Credit System', 'system_origin': 'South Korea', 'system_serving': 'Minaisa Club', 'establishment': '2005-07-20'}
# -----
# {'system_name': 'Tamworth Hours', 'system_type': 'Tamworth Hours\n\nHOURS System', 'system_origin': 'Canada', 'system_serving': 'Ontario', 'establishment': '2005-04-12'}
# -----
# {'system_name': 'Red de Trueque Solidaria', 'system_type': 'Red de Trueque Solidaria\n\nVoucher Currency System', 'system_origin': 'El Salvador', 'system_serving': 'Apulo, Jiboa, Espinal', 'establishment': '2005-04-04'}
# -----
# {'system_name': 'Red Empresarial de Trueque (RET)', 'system_type': 'Red Empresarial de Trueque (RET)\n\nMutual Credit System', 'system_origin': 'El Salvador', 'system_serving': 'San Salvador', 'establishment': '2005-04-04'}
# -----
# {'system_name': 'JEU', 'system_type': "JEU\n\nJardin d'Echange Universel", 'system_origin': 'France', 'system_serving': 'Francophonie', 'establishment': '2005-01-18'}
# -----
# {'system_name': 'Calgary Dollars', 'system_type': 'Calgary Dollars\n\nFiat Currency System', 'system_origin': 'Canada', 'system_serving': 'Calgary', 'establishment': '2004-11-29'}
# -----
# {'system_name': 'Community Oriented Mutual Economy', 'system_type': 'Community Oriented Mutual Economy\n\nFiat Currency System', 'system_origin': 'China', 'system_serving': 'Wanchai', 'establishment': '2004-11-25'}
# -----
# {'system_name': 'Tabu Shell Money', 'system_type': 'Tabu Shell Money\n\nTraditional / Cultural System', 'system_origin': 'Papua New Guinea', 'system_serving': 'Rabaul', 'establishment': '2004-11-25'}
# -----
# {'system_name': 'UDIS COMAL', 'system_type': 'UDIS COMAL\n\nVoucher Currency System', 'system_origin': 'Honduras', 'system_serving': 'Various rural areas', 'establishment': '2004-11-22'}
# -----
# {'system_name': 'LETS Svojpomoc', 'system_type': 'LETS Svojpomoc\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Slovakia', 'system_serving': 'Bratislava', 'establishment': '2004-11-18'}
# -----
# {'system_name': 'Thames Green Dollar Exchange', 'system_type': 'Thames Green Dollar Exchange\n\nMutual Credit System', 'system_origin': 'New Zealand', 'system_serving': 'Coromandel', 'establishment': '2004-11-16'}
# -----
# {'system_name': 'Madison Hours', 'system_type': 'Madison Hours\n\nHOURS System', 'system_origin': 'United States', 'system_serving': 'Madison, WI', 'establishment': '2004-11-12'}
# -----
# {'system_name': 'Thankyous at Friendly Favors', 'system_type': 'Thankyous at Friendly Favors\n\nMutual Credit System', 'system_origin': 'United States', 'system_serving': 'San Francisco Bay Area, California, USA', 'establishment': '2004-11-11'}
# -----
# {'system_name': 'ACV/Compartienda', 'system_type': 'ACV/Compartienda\n\nCommunity Barter System', 'system_origin': 'Mexico', 'system_serving': 'Virtual interaction amomg various communities', 'establishment': '2004-11-05'}
# -----
# {'system_name': 'Mitrapaap', 'system_type': 'Mitrapaap\n\nCommunity Barter System', 'system_origin': 'Thailand', 'system_serving': 'Chatujak', 'establishment': '2004-11-05'}
# -----
# {'system_name': 'PLENTY', 'system_type': 'PLENTY\n\nFiat Currency System', 'system_origin': 'United States', 'system_serving': 'central North Carolina', 'establishment': '2004-11-04'}
# -----
# {'system_name': 'RÉEL', 'system_type': 'RÉEL\n\nCommunity Way', 'system_origin': 'Canada', 'system_serving': 'Granby, Québec', 'establishment': '2004-11-04'}
# -----
# {'system_name': 'The St Augustine SunMoney', 'system_type': 'The St Augustine SunMoney', 'system_origin': 'United States', 'system_serving': 'St Augustine, Florida', 'establishment': '2004-11-04'}
# -----
# {'system_name': 'Göteborgs LETS', 'system_type': 'Göteborgs LETS\n\nLocal Exchange Trading System  (LETS)', 'system_origin': 'Sweden', 'system_serving': 'Göteborg', 'establishment': '2004-11-03'}
# -----
# {'system_name': 'Community Exchange System', 'system_type': 'Community Exchange System\n\nCommunity Exchange System', 'system_origin': 'South Africa', 'system_serving': 'International', 'establishment': '2004-11-01'}
# -----
# {'system_name': 'Hour Third Market Network (Tamworth Wing)', 'system_type': 'Hour Third Market Network (Tamworth Wing)\n\nHOURS System', 'system_origin': 'Canada', 'system_serving': 'Tamworth, Ontario', 'establishment': '2004-10-31'}
# -----
# {'system_name': 'H.A.N.D.S.', 'system_type': 'H.A.N.D.S.\n\nMutual Credit System', 'system_origin': 'New Zealand', 'system_serving': 'Takaka', 'establishment': '2004-10-31'}
# -----
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-186-3659ab89f366> in <module>()
#       9     for entry in each_entry:
#      10         ENTRY_DICT = {}
# ---> 11         entry_name = entry.find_all('ul')[0].find('a')
#      12         if entry_name:
#      13             #print(entry_name.text.strip())
#
# IndexError: list index out of range

# %%
df = pd.DataFrame(entries)
df
# Out:
#     establishment                                        system_name  \
# 0      2017-05-28                                           Hourcoin
# 1      2017-04-07                                        Timebank.cc
# 2      2017-02-13                                             COOPEK
# 3      2017-02-07               Compumatrix powered by Bitshares 2.0
# 4      2017-01-28                           Kasonga Business Network
# 5      2016-11-15                                         Red Rizoma
# 6      2016-07-16                                    ICU P2P Payment
# 7      2016-05-15                                         bambali.de
# 8      2016-03-06                  Red de Intercambio Solidario Saja
# 9      2016-02-18                                     www.ces.org.za
# 10     2016-02-10                                          Der Regio
# 11     2016-01-29                                Myyrmäen Aikapankki
# 12     2016-01-26                                               Colu
# 13     2015-12-26                                          TimesFree
# 14     2015-12-18                              CES Greater Vancouver
# 15     2015-12-17  Community Exchange System - Alaska ExchangeNet...
# 16     2015-12-15                                            Bitcoin
# 17     2015-12-14                       Thames Green Dollar Exchange
# 18     2015-12-14                                              Copín
# 19     2015-12-14                                       TIME BANKING
# 20     2015-12-14                          Community Exchange System
# 21     2015-12-08                               EcoXarxa Plana Baixa
# 22     2015-11-30                                Collective Currency
# 23     2015-11-17                              Hudson Valley Current
# 24     2015-11-09                                              KoiNo
# 25     2015-11-05                                      Kapital Truth
# 26     2015-08-17                                                BBX
# 27     2015-08-08                         ECU _ Alternative Currency
# 28     2015-05-27                                              Tibex
# 29     2015-05-11                                              Nuevo
# ..            ...                                                ...
# 280    2005-08-09                                        Hanbat LETS
# 281    2005-07-30                                     New Moray LETS
# 282    2005-07-29                             Fourth Corner Exchange
# 283    2005-07-29                                          Rheingold
# 284    2005-07-28                                Salt Spring Dollars
# 285    2005-07-28                                    にほうコミュニティ交換システム
# 286    2005-07-21                                             NOPPES
# 287    2005-07-21                                           Landmark
# 288    2005-07-20                                   fm(future money)
# 289    2005-04-12                                     Tamworth Hours
# 290    2005-04-04                           Red de Trueque Solidaria
# 291    2005-04-04                   Red Empresarial de Trueque (RET)
# 292    2005-01-18                                                JEU
# 293    2004-11-29                                    Calgary Dollars
# 294    2004-11-25                  Community Oriented Mutual Economy
# 295    2004-11-25                                   Tabu Shell Money
# 296    2004-11-22                                         UDIS COMAL
# 297    2004-11-18                                     LETS Svojpomoc
# 298    2004-11-16                       Thames Green Dollar Exchange
# 299    2004-11-12                                      Madison Hours
# 300    2004-11-11                       Thankyous at Friendly Favors
# 301    2004-11-05                                   ACV/Compartienda
# 302    2004-11-05                                          Mitrapaap
# 303    2004-11-04                                             PLENTY
# 304    2004-11-04                                               RÉEL
# 305    2004-11-04                          The St Augustine SunMoney
# 306    2004-11-03                                     Göteborgs LETS
# 307    2004-11-01                          Community Exchange System
# 308    2004-10-31          Hour Third Market Network (Tamworth Wing)
# 309    2004-10-31                                         H.A.N.D.S.
#
#         system_origin                                     system_serving  \
# 0      United Kingdom                                              Wales
# 1         Netherlands                      The Hague - Brussels - Lisbon
# 2              France                                             COOPEK
# 3       United States                                          Worldwide
# 4               Kenya                       Kyangwali Refugee Settlement
# 5           Argentina                                            Córdoba
# 6               Spain                                          Worldwide
# 7             Germany                                        Deutschland
# 8               Spain                                          Cantabria
# 9               Spain                                           Zaragoza
# 10            Germany                                            München
# 11            Finland                                  Myyrmäen suuralue
# 12             Israel                                               Colu
# 13      United States                                          Worldwide
# 14             Canada                                  Greater Vancouver
# 15      United States                                             Alaska
# 16             Israel                                  bitcoin Community
# 17        New Zealand                                             Thames
# 18              Spain                                           Asturias
# 19       South Africa                                       CAMEROUNAISE
# 20             Canada  Revelstoke Alternative Goods and Services Exch...
# 21              Spain                               Comunidad Valenciana
# 22           Barbados                                          St. James
# 23      United States                                      Hudson Valley
# 24             Greece                             Kalamaria/Thessaloniki
# 25              Spain                                             Global
# 26          Hong Kong                                             Global
# 27      United States                                          worldwide
# 28              Italy                                              Lazio
# 29          Guatemala                                     Quetzaltenango
# ..                ...                                                ...
# 280       South Korea                                        Hanbat LETS
# 281    United Kingdom                                              Moray
# 282     United States                                  Pacific Northwest
# 283           Germany                                         Düsseldorf
# 284            Canada                                 Salt Spring Island
# 285             Japan                                    福岡・大分県境の山国川河口地域
# 286       Netherlands                                          Amsterdam
# 287           Germany                                          Reinstädt
# 288       South Korea                                       Minaisa Club
# 289            Canada                                            Ontario
# 290       El Salvador                              Apulo, Jiboa, Espinal
# 291       El Salvador                                       San Salvador
# 292            France                                       Francophonie
# 293            Canada                                            Calgary
# 294             China                                            Wanchai
# 295  Papua New Guinea                                             Rabaul
# 296          Honduras                                Various rural areas
# 297          Slovakia                                         Bratislava
# 298       New Zealand                                         Coromandel
# 299     United States                                        Madison, WI
# 300     United States            San Francisco Bay Area, California, USA
# 301            Mexico      Virtual interaction amomg various communities
# 302          Thailand                                           Chatujak
# 303     United States                             central North Carolina
# 304            Canada                                     Granby, Québec
# 305     United States                              St Augustine, Florida
# 306            Sweden                                           Göteborg
# 307      South Africa                                      International
# 308            Canada                                  Tamworth, Ontario
# 309       New Zealand                                             Takaka
#
#                                            system_type
# 0              Hourcoin\n\nBlock chain crypto-currency
# 1                      Timebank.cc\n\nTime Bank System
# 2                  COOPEK\n\nGlobal financial currency
# 3    Compumatrix powered by Bitshares 2.0\n\nBlock ...
# 4    Kasonga Business Network\n\nVoucher Currency S...
# 5              Red Rizoma\n\nCommunity Exchange System
# 6         ICU P2P Payment\n\nGlobal financial currency
# 7         bambali.de\n\nMarketplace Currency (ie. RGT)
# 8    Red de Intercambio Solidario Saja\n\nCommunity...
# 9          www.ces.org.za\n\nCommunity Exchange System
# 10                Der Regio\n\nVoucher Currency System
# 11    Myyrmäen Aikapankki\n\nCommunity Exchange System
# 12                 Colu\n\nBlock chain crypto-currency
# 13           TimesFree\n\nCommunity Cooperation System
# 14   CES Greater Vancouver\n\nCommunity Exchange Sy...
# 15   Community Exchange System - Alaska ExchangeNet...
# 16                           Bitcoin\n\nCryptocurrency
# 17   Thames Green Dollar Exchange\n\nLocal Exchange...
# 18                  Copín\n\nCommunity Exchange System
# 19             TIME BANKING\n\nCommunity Barter System
# 20              Community Exchange System\n\nLETSystem
# 21   EcoXarxa Plana Baixa\n\nLocal Exchange Trading...
# 22         Collective Currency\n\nMutual Credit System
# 23    Hudson Valley Current\n\nCommunity Barter System
# 24                                  KoiNo\n\nLETSystem
# 25   Kapital Truth\n\nReconocimiento diario de méri...
# 26                   BBX\n\nCommercial Exchange System
# 27   ECU _ Alternative Currency\n\nGlobal financial...
# 28                 Tibex\n\nCommercial Exchange System
# 29                    Nuevo\n\nCommunity Barter System
# ..                                                 ...
# 280  Hanbat LETS\n\nLocal Exchange Trading System  ...
# 281  New Moray LETS\n\nLocal Exchange Trading Syste...
# 282  Fourth Corner Exchange\n\nCommunity Cooperatio...
# 283                          Rheingold\n\nREGIO System
# 284     Salt Spring Dollars\n\nVoucher Currency System
# 285            にほうコミュニティ交換システム\n\nMutual Credit System
# 286                     NOPPES\n\nMutual Credit System
# 287                           Landmark\n\nREGIO System
# 288           fm(future money)\n\nMutual Credit System
# 289                     Tamworth Hours\n\nHOURS System
# 290  Red de Trueque Solidaria\n\nVoucher Currency S...
# 291  Red Empresarial de Trueque (RET)\n\nMutual Cre...
# 292                  JEU\n\nJardin d'Echange Universel
# 293            Calgary Dollars\n\nFiat Currency System
# 294  Community Oriented Mutual Economy\n\nFiat Curr...
# 295  Tabu Shell Money\n\nTraditional / Cultural System
# 296              UDIS COMAL\n\nVoucher Currency System
# 297  LETS Svojpomoc\n\nLocal Exchange Trading Syste...
# 298  Thames Green Dollar Exchange\n\nMutual Credit ...
# 299                      Madison Hours\n\nHOURS System
# 300  Thankyous at Friendly Favors\n\nMutual Credit ...
# 301        ACV/Compartienda\n\nCommunity Barter System
# 302               Mitrapaap\n\nCommunity Barter System
# 303                     PLENTY\n\nFiat Currency System
# 304                              RÉEL\n\nCommunity Way
# 305                          The St Augustine SunMoney
# 306  Göteborgs LETS\n\nLocal Exchange Trading Syste...
# 307  Community Exchange System\n\nCommunity Exchang...
# 308  Hour Third Market Network (Tamworth Wing)\n\nH...
# 309                 H.A.N.D.S.\n\nMutual Credit System
#
# [310 rows x 5 columns]

# %%
df['establishment'] = df['establishment'].str.extract(r"(\d\d\d\d)")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['system_type'] = df['system_type'].str.extract(r"\n\n(.*)")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   establishment                           system_name   system_origin  \
# 0          2017                              Hourcoin  United Kingdom
# 1          2017                           Timebank.cc     Netherlands
# 2          2017                                COOPEK          France
# 3          2017  Compumatrix powered by Bitshares 2.0   United States
# 4          2017              Kasonga Business Network           Kenya
#
#                   system_serving                  system_type
# 0                          Wales  Block chain crypto-currency
# 1  The Hague - Brussels - Lisbon             Time Bank System
# 2                         COOPEK    Global financial currency
# 3                      Worldwide  Block chain crypto-currency
# 4   Kyangwali Refugee Settlement      Voucher Currency System

# %%
df.to_csv("currencies.csv", index=False)

# %%
df['establishment'].value_counts().sort_index(ascending=False).plot(kind='barh')
