# 303  le_systems_admin.php?action=view&systemId=13&s...
# 304  le_systems_admin.php?action=view&systemId=12&s...
# 305  le_systems_admin.php?action=view&systemId=9&s_...
# 306  le_systems_admin.php?action=view&systemId=8&s_...
# 307  le_systems_admin.php?action=view&systemId=7&s_...
# 308  le_systems_admin.php?action=view&systemId=6&s_...
#
# [309 rows x 1 columns]

# %%
df['entry_link'] = df['entry_link'].str.extract(r"systemId=(.*)&s_le_countryId")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     entry_link
# 0          498
# 1          497
# 2          495
# 3          494
# 4          493
# 5          492
# 6          491
# 7          489
# 8          488
# 9          487
# 10         486
# 11         485
# 12         484
# 13         483
# 14         482
# 15         481
# 16         480
# 17         479
# 18         478
# 19         477
# 20         475
# 21         473
# 22         471
# 23         470
# 24         469
# 25         468
# 26         467
# 27         466
# 28         465
# 29         464
# ..         ...
# 279         56
# 280         50
# 281         49
# 282         48
# 283         47
# 284         46
# 285         42
# 286         41
# 287         40
# 288         37
# 289         36
# 290         35
# 291         33
# 292         30
# 293         29
# 294         28
# 295         26
# 296         25
# 297         22
# 298         21
# 299         20
# 300         18
# 301         16
# 302         14
# 303         13
# 304         12
# 305          9
# 306          8
# 307          7
# 308          6
#
# [309 rows x 1 columns]

# %%
# THIS SITE IS A MESS. CANNOT SCRAPE IT WITHOUT GETTING WRONG RESULTS :(

# def process_entry(row):
#     driver = webdriver.Chrome()
#     driver.get("http://complementarycurrency.org/ccDatabase/le_systems_admin.php?action=view&systemId=" + row['entry_link'] + "&s_le_countryId=83&sysCallBack=les_public_splash.php")
#     entry_name = driver.find_element_by_xpath('/html/body/h1[2]')
#     print('entry_name:', entry_name.text.strip())
#     entry_type = driver.find_element_by_xpath('/html/body/h1[2]/span')
#     print('entry_type:', entry_type.text.strip())
#     organization_type = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[7]/td')
#     print('organization_type:', organization_type.text.strip())
#     entry_status = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[9]/td')
#     print('entry_status:', entry_status.text.strip())
#     print("-----")
        
# df.apply(process_entry, axis=1)

# %%
# entries = []
# for page in range(0,20):
#     driver = webdriver.Chrome()
#     driver.get("http://complementarycurrency.org/ccDatabase/le_systems_admin.php?action=view&systemId=" + str(page) + "&s_le_countryId=83&sysCallBack=les_public_splash.php")
#     html = driver.page_source
#     doc = BeautifulSoup(html, 'html.parser')
#     all_entries = doc.find('body')
#     for entry in all_entries:
#         ENTRY_DICT = {}
#         entry_name = entry.find_all('h1')
#         if entry_name:
#             ENTRY_DICT['system_name'] = entry_name.text.strip()
#         entry_type = entry.find_all('h1').find('span')
#         if entry_type:
#             ENTRY_DICT['system_type'] = entry_type.text.strip()
#         my_table = entry.find("table", class_="list")
#         organization_type = my_table.find_all('tr')[6].find('td')
#         if organization_type:
#             ENTRY_DICT['organization_type'] = organization_type.text.strip()
#         entry_status = my_table.find_all('tr')[8].find('td')
#         if entry_status:
#             ENTRY_DICT['entry_status'] = entry_status.text.strip()
#         entry_starting_year = my_table.find_all('tr')[9].find('td')
#         if entry_starting_year:
#             ENTRY_DICT['entry_starting_year'] = entry_starting_year.text.strip()
#         entries.append(ENTRY_DICT)
#         print(ENTRY_DICT)
#         print("-----")
    
# ___________________________________________
    
# #     for entry in each_entry:
# #         ENTRY_DICT = {}
# #         entry_name = entry.find_all('ul')[0].find('a')
# #         if entry_name:
# #             #print(entry_name.text.strip())
# #             ENTRY_DICT['system_name'] = entry_name.text.strip()
# #         entry_type = entry.find_all('ul')[0].find('li')
# #         if entry_type:
# #             #print(entry_type.text.strip())
# #             ENTRY_DICT['system_type'] = entry_type.text.strip()
# #         entry_origin = entry.find_all('td')[2]
# #         if entry_origin:
# #             #print(entry_origin.text.strip())
# #             ENTRY_DICT['system_origin'] = entry_origin.text.strip()
# #         entry_serving = entry.find_all('td')[1]
# #         if entry_serving:
# #             #print(entry_serving.text.strip())
# #             ENTRY_DICT['system_serving'] = entry_serving.text.strip()
# #         entry_year_of_establishment = entry.find_all('td')[3]
# #         if entry_year_of_establishment:
# #             #print(entry_year_of_establishment.text.strip())
# #             ENTRY_DICT['establishment'] = entry_year_of_establishment.text.strip()
# #         entries.append(ENTRY_DICT)
# #         print(ENTRY_DICT)
# #         print("-----")

# %%
#SOME MANUAL WORK :(

new_df = pd.read_excel("currencies_all.xlsx")
new_df
# Out:
#                                            system_name  establishment  \
# 0                                             Hourcoin           2017
# 1                                          Timebank.cc           2013
# 2                 Compumatrix powered by Bitshares 2.0           2006
# 3                             Kasonga Business Network           2016
# 4                                           Red Rizoma           2016
# 5                                      ICU P2P Payment           2016
# 6                                           bambali.de           2004
# 7                    Red de Intercambio Solidario Saja           2014
# 8                                       www.ces.org.za           2016
# 9                                            Der Regio           2003
# 10                                 Myyrmäen Aikapankki           2014
# 11                                                Colu           2016
# 12                                           TimesFree           2015
# 13                               CES Greater Vancouver           2012
# 14   Community Exchange System - Alaska ExchangeNet...           2013
# 15                                             Bitcoin           2008
# 16                        Thames Green Dollar Exchange           1992
# 17                                               Copín           2012
# 18                                        TIME BANKING           2014
# 19                           Community Exchange System           2012
# 20                                EcoXarxa Plana Baixa           2013
# 21                                 Collective Currency           2011
# 22                               Hudson Valley Current           2013
# 23                                               KoiNo           2012
# 24                                       Kapital Truth           2012
# 25                                                 BBX           1993
# 26                          ECU _ Alternative Currency           2015
# 27                                               Tibex           2013
# 28                                               Nuevo           2014
# 29                          Estrela Community Exchange           2012
# ..                                                 ...            ...
# 266                                    Toronto Dollars           1998
# 267                                        Hanbat LETS           1999
# 268                                     New Moray LETS           1997
# 269                             Fourth Corner Exchange           2004
# 270                                          Rheingold           2005
# 271                                Salt Spring Dollars           2001
# 272                                    にほうコミュニティ交換システム           2005
# 273                                             NOPPES           1993
# 274                                           Landmark           2005
# 275                                   fm(future money)           1998
# 276                                     Tamworth Hours           2004
# 277                           Red de Trueque Solidaria           2001
# 278                   Red Empresarial de Trueque (RET)           2002
# 279                                                JEU           1998
# 7                Community Exchange System
# 8                Community Exchange System
# 9                  Voucher Currency System
# 10               Community Exchange System
# 11             Block chain crypto-currency
# 12            Community Cooperation System
# 13               Community Exchange System
# 14               Community Exchange System
# 15                          Cryptocurrency
# 16   Local Exchange Trading System  (LETS)
# 17               Community Exchange System
# 18                 Community Barter System
# 19                               LETSystem
# 20   Local Exchange Trading System  (LETS)
# 21                    Mutual Credit System
# 22                 Community Barter System
# 23                               LETSystem
# 24   Reconocimiento diario de mérito mutuo
# 25              Commercial Exchange System
# 26               Global financial currency
# 27              Commercial Exchange System
# 28                 Community Barter System
# 29                    Mutual Credit System
# ..                                     ...
# 266                Voucher Currency System
# 267  Local Exchange Trading System  (LETS)
# 268  Local Exchange Trading System  (LETS)
# 269           Community Cooperation System
# 270                           REGIO System
# 271                Voucher Currency System
# 272                   Mutual Credit System
# 273                   Mutual Credit System
# 274                           REGIO System
# 275                   Mutual Credit System
# 276                           HOURS System
# 277                Voucher Currency System
# 278                   Mutual Credit System
# 279             Jardin d'Echange Universel
# 280                   Fiat Currency System
# 281                   Fiat Currency System
# 282          Traditional / Cultural System
# 283                Voucher Currency System
# 284  Local Exchange Trading System  (LETS)
# 285                   Mutual Credit System
# 286                           HOURS System
# 287                   Mutual Credit System
# 288                Community Barter System
# 289                Community Barter System
# 290                   Fiat Currency System
# 291                          Community Way
# 292  Local Exchange Trading System  (LETS)
# 293              Community Exchange System
# 294                           HOURS System
# 295                   Mutual Credit System
#
#                                      organization  \
# 0                              Private Enterprise
# 1     Community-Based Organization (Unregistered)
# 2                              Private Enterprise
# 3        Non-Government Organization (Registered)
# 4     Community-Based Organization (Unregistered)
# 5    Non-Government Organization (Registered)\n\n
# 6                              Private Enterprise
# 7     Community-Based Organization (Unregistered)
# 8     Community-Based Organization (Unregistered)
# 9        Non-Government Organization (Registered)
# 10    Community-Based Organization (Unregistered)
# 11                             Private Enterprise
# 12                             Private Enterprise
# 13    Community-Based Organization (Unregistered)
# 14    Community-Based Organization (Unregistered)
# 15                       Cooperative Organization
# 16    Community-Based Organization (Unregistered)
# 17                       Cooperative Organization
# 18    Community-Based Organization (Unregistered)
# 19    Community-Based Organization (Unregistered)
# 20    Community-Based Organization (Unregistered)
# 21                             Private Enterprise
# 22       Non-Government Organization (Registered)
# 23    Community-Based Organization (Unregistered)
# 24                                            NaN
# 25                             Private Enterprise
# 26    Community-Based Organization (Unregistered)
# 27                             Private Enterprise
# 28    Community-Based Organization (Unregistered)
# 29    Community-Based Organization (Unregistered)
# ..                                            ...
# 266                            Private Enterprise
# 267   Community-Based Organization (Unregistered)
# 268   Community-Based Organization (Unregistered)
# 269                            Private Enterprise
# 270      Non-Government Organization (Registered)
# 271      Non-Government Organization (Registered)
# 272   Community-Based Organization (Unregistered)
# 273                      Cooperative Organization
# 274      Non-Government Organization (Registered)
# 275      Non-Government Organization (Registered)
# 276   Community-Based Organization (Unregistered)
# 277      Non-Government Organization (Registered)
# 278      Non-Government Organization (Registered)
# 279   Community-Based Organization (Unregistered)
# 280      Non-Government Organization (Registered)
# 281      Non-Government Organization (Registered)
# 282   Community-Based Organization (Unregistered)
# 283      Non-Government Organization (Registered)
# 284   Community-Based Organization (Unregistered)
# 285   Community-Based Organization (Unregistered)
# 286                      Cooperative Organization
# 287   Community-Based Organization (Unregistered)
# 288      Non-Government Organization (Registered)
# 289   Community-Based Organization (Unregistered)
# 290                            Private Enterprise
# 291   Community-Based Organization (Unregistered)
# 292      Non-Government Organization (Registered)
# 293      Non-Government Organization (Registered)
# 294                            Private Enterprise
# 295   Community-Based Organization (Unregistered)
#
#                                             medium  \
# 0                       Cryptocurrency Transaction
# 1                     Time Bank / Service Exchange
# 2                           Electronic Transaction
# 3                                         Vouchers
# 4                  Trueke Directo + Moneda Comunal
# 5                           Electronic Transaction
# 6                           Electronic Transaction
# 7        Electronic Transaction using CES Software
# 8        Electronic Transaction using CES Software
# 9                                    Notes / Bills
# 10                                       Myyr-Tovi
# 11                                             NaN
# 12                    Time Bank / Service Exchange
# 13       Electronic Transaction using CES Software
# 14       Electronic Transaction using CES Software
# 15   Public Decentralized Ledger, Tradeable Tokens
# 16                                 Barter Exchange
# 17       Electronic Transaction using CES Software
# 18       Electronic Transaction using CES Software
# 19                          Electronic Transaction
# 20       Electronic Transaction using CES Software
# 21                                 Barter Exchange
# 22    Electronic Transaction using Cyclos Software
# 23    Electronic Transaction using Cyclos Software
# 24                                   Coin or Token
# 25                                 Barter Exchange
# 26    Electronic Transaction using Cyclos Software
# 27                          Electronic Transaction
# 28                  Notes + Electronic Transaction
# 29                          Electronic Transaction
# ..                                             ...
# 266                                  Notes / Bills
# 267                                  Notes / Bills
# 268                                       Accounts
# 269                             Accounts + Cheques
# 270                                  Notes / Bills
# 271                                  Notes / Bills
# 272                                       Accounts
# 273                               Accounts + Notes
# 274                                  Notes / Bills
# 275                               Accounts + Notes
# 276                                  Notes / Bills
# 277                                       Vouchers
# 278                               Accounts + Notes
# 279        Direct Recording in Paper Account Books
# 280                               Accounts + Notes
# 281                                  Notes / Bills
# 282                  Traditional / Cultural Medium
# 283                                  Notes / Bills
# 284                         Electronic Transaction
# 285                                  Notes / Bills
# 286                                  Notes / Bills
# 287                         Electronic Transaction
# 288                                     Smart Card
# 289                                Barter Exchange
# 290                                  Notes / Bills
# 291                         Electronic Transaction
# 292                         Electronic Transaction
# 293                         Electronic Transaction
# 294                                  Notes / Bills
# 295                               Accounts + Notes
#
#                                                unit  \
# 0                                     Units of Time
# 1                                     Units of Time
# 2                        Units of Independent Value
# 3             Units of National Currency Equivalent
# 4                                     Units of Time
# 5             Units of National Currency Equivalent
# 6             Units of National Currency Equivalent
# 7    Several (one or many, defined by users/groups)
# 8             Units of National Currency Equivalent
# 9             Units of National Currency Equivalent
# 10                                    Units of Time
# 11                                              NaN
# 12                                    Units of Time
# 13            Units of National Currency Equivalent
# 14            Units of National Currency Equivalent
# 15               Divisible Fractions of Fixed Total
# 16   Several (one or many, defined by users/groups)
# 17            Units of National Currency Equivalent
# 18                                    Units of Time
# 19            Units of National Currency Equivalent
# 20   Several (one or many, defined by users/groups)
# 21     Units of National Currency Equivalent + Time
# 22            Units of National Currency Equivalent
# 23            Units of National Currency Equivalent
# 24                       Units of Independent Value
# 25         Units of Currency / Commodity / Resource
# 26                       Units of Independent Value
# 27            Units of National Currency Equivalent
# 28            Units of National Currency Equivalent
# 29                                              NaN
# ..                                              ...
# 266           Units of National Currency Equivalent
# 267                                   Units of Time
# 268           Units of National Currency Equivalent
# 269                      Units of Independent Value
# 270           Units of National Currency Equivalent
# 271           Units of National Currency Equivalent
# 272           Units of National Currency Equivalent
# 273           Units of National Currency Equivalent
# 274           Units of National Currency Equivalent
# 275           Units of National Currency Equivalent
# 276                                   Units of Time
# 277           Units of National Currency Equivalent
# 278           Units of National Currency Equivalent
# 279    Units of National Currency Equivalent + Time
# 280           Units of National Currency Equivalent
# 281                                   Units of Time
# 282                      Units of Independent Value
# 283           Units of National Currency Equivalent
# 284                                   Units of Time
# 285           Units of National Currency Equivalent
# 286                                   Units of Time
# 287           Units of National Currency Equivalent
# 288           Units of National Currency Equivalent
# 289                      Units of Independent Value
# 290                                   Units of Time
# 291           Units of National Currency Equivalent
# 292           Units of National Currency Equivalent
# 293           Units of National Currency Equivalent
# 294                                   Units of Time
# 295           Units of National Currency Equivalent
#
#              source_of_funding  \
# 0            Private Donations
# 1                   No Funding
# 2                   No Funding
# 3                   No Funding
# 4                          NaN
# 5    Internal Currency Charges
# 6                          NaN
# 7                   No Funding
# 8                   No Funding
# 9             External Funding
# 10                  No Funding
# 11                         NaN
# 12            External Funding
# 13           Private Donations
# 14                  No Funding
# 15                  No Funding
# 16   Internal Currency Charges
# 17                  No Funding
# 18           Private Donations
# 19                  No Funding
# 20                  No Funding
# 21   Internal Currency Charges
# 22   Internal Currency Charges
# 23                  No Funding
# 24                  No Funding
# 25                  No Funding
# 26            External Funding
# 27                  No Funding
# 28           Private Donations
# 29                  No Funding
# ..                         ...
# 266  Internal Currency Charges
# 267  Internal Currency Charges
# 268                        NaN
# 269  Internal Currency Charges
# 270           External Funding
# 271          Private Donations
# 272          Private Donations
# 273          Private Donations
# 274                 No Funding
# 275          Private Donations
# 276          Private Donations
# 277          Private Donations
# 278           External Funding
# 279                 No Funding
# 280           External Funding
# 281           External Funding
# 282  Internal Currency Charges
# 283           External Funding
# 284  Internal Currency Charges
# 285  Internal Currency Charges
# 286           External Funding
# 287  Internal Currency Charges
# 288           External Funding
# 289           External Funding
# 290          Private Donations
# 291  Internal Currency Charges
# 292  Internal Currency Charges
# 293  Internal Currency Charges
# 294          Private Donations
# 295           External Funding
#
#                                                purpose  membership
# 0           Contributing towards a Sustainable Society         NaN
# 1                                       Social Justice       770.0
# 2        Micro / Small / Medium Enterprise Development      2150.0
# 3                                          All reasons       120.0
# 4                                          All reasons         NaN
# 5                             Avoiding Monetary Crisis   1000000.0
# 6                                          All reasons         NaN
# 7                                          All reasons        54.0
# 8                 Economic progress and social justice       400.0
# 9                                          All reasons       183.0
# 10          Contributing towards a Sustainable Society         NaN
# 11                                                 NaN         NaN
# 12                                         All reasons         NaN
# 13                                         All reasons        28.0
# 14                   Reduce Need for National Currency         NaN
# 15             Enabling financial development globally         NaN
# 16                                         All reasons        60.0
# 17                                         All reasons       122.0
# 18                               Community Development         1.0
# 19                                         All reasons        72.0
# 20                                         All reasons       140.0
# 21                                         All reasons       200.0
# 22                                         All reasons       205.0
# 23                   Sustainability and social justice      1000.0
# 24                                    Moral imperative         NaN
# 25                         Activating the Local Market     70000.0
# 26                                         All reasons         NaN
# 27                         Supporting local businesses       300.0
# 28                                    Moral imperative       120.0
# 29                   Sustainability and social justice       180.0
# ..                                                 ...         ...
# 266                              Community Development         NaN
# 267                              Community Development       600.0
# 268                                        All reasons       400.0
# 269                                        All reasons       900.0
# 270                                Create a New Market         7.0
# 271                                        All reasons      4000.0
# 272                                        All reasons        22.0
# 273                                        All reasons       750.0
# 274                        Activating the Local Market        60.0
# 275                  Enhancing members quality of life       300.0
# 276                                        All reasons        50.0
# 277                              Community Development        50.0
# 278      Micro / Small / Medium Enterprise Development       200.0
# 279                                 Social Integration     15000.0
# 280                                        All reasons       700.0
# 281                              Community Development       700.0
# 282                Preservation of Traditional Culture     75000.0
# 283                         Reduce prices to consumers         NaN
# 284                                        All reasons        40.0
# 285                  Enhancing members quality of life       100.0
# 286                              Community Development       125.0
# 287                                 Social Integration      4000.0
# 288                                        All reasons        80.0
# 289                  Reduce Need for National Currency        20.0
# 290                                        All reasons       200.0
# 291                              Community Development        75.0
# 292                                        All reasons        60.0
# 293                                        All reasons     26871.0
# 294  Teach people how to create & spend local currency        70.0
# 295                              Community Development       250.0
#
# [296 rows x 11 columns]

# %%
new_df['establishment'].value_counts().head()
# Out:
# 2009    25
# 2012    22
# 2008    22
# 2013    20
# 2006    20
# Name: establishment, dtype: int64

# %%
new_df['establishment'].value_counts().sort_index().plot(kind='bar', figsize=(15,5))

# %%
new_df['country'].value_counts().head(10)
# Out:
# United States     49
# Germany           28
# Australia         25
# Canada            23
# Belgium           19
# United Kingdom    15
# Spain             14
# Venezuela         13
# Netherlands       12
# New Zealand       12
# Name: country, dtype: int64

# %%
new_df['system_name'].describe()
# Out:
# count                              296
# unique                             291
# top       Thames Green Dollar Exchange
# freq                                 2
# Name: system_name, dtype: object

# %%
new_df['country'].value_counts().head(10).plot(kind='barh', figsize=(12,5))

# %%
new_df['serving'].value_counts().head(10)
# Out:
# Worldwide            9
# International        7
# Global               6
# Wallonie             4
# Deutschland          2
# National             2
# Melbourne            2
# Française            2
# Lazio                2
# Rio Grande do Sul    2
# Name: serving, dtype: int64

# %%
new_df.head()
# Out:
#                             system_name  establishment         country  \
# 0                              Hourcoin           2017  United Kingdom
# 1                           Timebank.cc           2013     Netherlands
# 2  Compumatrix powered by Bitshares 2.0           2006   United States
# 3              Kasonga Business Network           2016           Kenya
# 4                            Red Rizoma           2016       Argentina
#
#                          serving                  system_type  \
# 0                          Wales  Block chain crypto-currency
# 1  The Hague - Brussels - Lisbon             Time Bank System
# 2                      Worldwide  Block chain crypto-currency
# 3   Kyangwali Refugee Settlement      Voucher Currency System
# 4                        Córdoba    Community Exchange System
#
#                                   organization  \
# 0                           Private Enterprise
# 1  Community-Based Organization (Unregistered)
# 2                           Private Enterprise
# 3     Non-Government Organization (Registered)
# 4  Community-Based Organization (Unregistered)
#
#                             medium                                   unit  \
# 0       Cryptocurrency Transaction                          Units of Time
# 1     Time Bank / Service Exchange                          Units of Time
# 2           Electronic Transaction             Units of Independent Value
# 3                         Vouchers  Units of National Currency Equivalent
# 4  Trueke Directo + Moneda Comunal                          Units of Time
#
#    source_of_funding                                        purpose  \
# 0  Private Donations     Contributing towards a Sustainable Society
# 1         No Funding                                 Social Justice
# 2         No Funding  Micro / Small / Medium Enterprise Development
# 3         No Funding                                    All reasons
# 4                NaN                                    All reasons
#
#    membership
# 0         NaN
# 1       770.0
# 2      2150.0
# 3       120.0
# 4         NaN

# %%
new_df['source_of_funding'].value_counts()
# Out:
# No Funding                   80
# Private Donations            53
# External Funding             50
# Internal Currency Charges    44
# External Currency Charges    17
# Name: source_of_funding, dtype: int64

# %%
new_df['source_of_funding'].value_counts().plot(kind='barh')

# %%
new_df['unit'].value_counts()
# Out:
# Units of National Currency Equivalent             134
# Units of Time                                      64
# Units of Independent Value                         32
# Several (one or many, defined by users/groups)     23
# Units of National Currency Equivalent + Time        9
# Units of Currency / Commodity / Resource            7
# Divisible Fractions of Fixed Total                  5
# Units of Commodity / Resource                       4
# Precious Metals                                     4
# Kilograms Greenhouse Gas Reduced                    2
# Hourly Minimal Wage                                 1
# Unité indéxée sur devise nationale + temps          1
# Units of National Currency Equivalent\n             1
# \nUnits of National Currency Equivalent             1
# Name: unit, dtype: int64

# %%
new_df['unit'].value_counts().plot(kind='barh', figsize=(10,5))

# %%
new_df['organization'].value_counts()
# Out:
# Community-Based Organization (Unregistered)     129
# Non-Government Organization (Registered)         80
# Private Enterprise                               50
# Cooperative Organization                         18
# Community Exchange System (CES)                   1
# Operating                                         1
# Non-Government Organization (Registered)\n\n      1
# Independent                                       1
# Name: organization, dtype: int64

# %%
new_df['system_type'].value_counts().head(10)
# Out:
# Local Exchange Trading System  (LETS)    46
# Mutual Credit System                     29
# Community Exchange System                28
# LETSystem                                22
# Time Bank System                         14
# Fiat Currency System                     14
# Voucher Currency System                  14
# Sistema de Trueke                        13
# Commercial Exchange System               12
# REGIO System                              9
# Name: system_type, dtype: int64

# %%
new_df['medium'].value_counts()
# Out:
# Electronic Transaction                              61
# Notes / Bills                                       42
# Electronic Transaction using CES Software           26
# Barter Exchange                                     25
# Accounts                                            25
# Electronic Transaction using Cyclos Software        14
# Accounts + Notes                                    13
# Notes + Electronic Transaction                       9
# Vouchers                                             8
# Accounts + Cheques                                   8
# Coin or Token                                        7
# Web Platform                                         7
# Check, Member Card, Telephone, or Internet           4
# Time Bank / Service Exchange                         4
# Accounts + Vouchers                                  4
# Traditional / Cultural Medium                        3
# Member Card                                          3
# Smart Card                                           2
# Accounts + Telephone                                 2
# Telephone or Internet                                2
# Direct Recording in Paper Account Books              2
# Electronic Transaction using Ripple Software         2
# Time Exchange                                        1
# Myyr-Tovi                                            1
# Transaction Electronique + Carnet                    1
# Electronic Transaction using LE UK software          1
# Globalized Basket                                    1
# Accounts, Cheques, Contracts, Markets, and Cash.     1
# Travel Booklets                                      1
# Crom econometric symbol                              1
# Plastic Coins                                        1
# Transactions automatisées via La Banque du Temps     1
# Cryptocurrency Transaction                           1
# Only Telephone Transactions Between Accounts         1
# Public Decentralized Ledger, Tradeable Tokens        1
# Transations électroniques + coupons + téléphone      1
# Trueke Directo + Moneda Comunal                      1
# Accounts + telephone + QR code wallet                1
# Name: medium, dtype: int64

# %%
pd.set_option("display.max_rows",400)

new_df[new_df['medium'] == 'Vouchers'].sort_values(by='country')
# Out:
#                                 system_name  establishment      country  \
# 277                Red de Trueque Solidaria           2001  El Salvador
# 95                                   Mesure           2011       France
# 119                                Kékfrank           2009      Hungary
# 3                  Kasonga Business Network           2016        Kenya
# 46                              Bangla Pesa           2013        Kenya
# 232  Invercargill Barter & Exchange Systems           1991  New Zealand
# 226                           Boon Kud Chum           1998     Thailand
# 227                              Jai System           2005     Thailand
#
#                           serving                          system_type  \
# 277         Apulo, Jiboa, Espinal              Voucher Currency System
# 95                      Française  Monnaie Locale Complémentaire (MLC)
# 119                 Region Sopron              Voucher Currency System
# 3    Kyangwali Refugee Settlement              Voucher Currency System
# 46                Bangladesh Slum                 Mutual Credit System
# 232                     Southland              Community Barter System
# 226        Satisuk Ampur Kud Chum                 Mutual Credit System
# 227    Non Taklang Ampur Nonsoong              Voucher Currency System
#
#                                     organization    medium  \
# 277     Non-Government Organization (Registered)  Vouchers
# 95   Community-Based Organization (Unregistered)  Vouchers
# 119                     Cooperative Organization  Vouchers
# 3       Non-Government Organization (Registered)  Vouchers
# 46      Non-Government Organization (Registered)  Vouchers
# 232  Community-Based Organization (Unregistered)  Vouchers
# 226     Non-Government Organization (Registered)  Vouchers
# 227     Non-Government Organization (Registered)  Vouchers
#
#                                       unit          source_of_funding  \
# 277  Units of National Currency Equivalent          Private Donations
# 95   Units of National Currency Equivalent  Internal Currency Charges
# 119  Units of National Currency Equivalent  External Currency Charges
# 3    Units of National Currency Equivalent                 No Funding
# 46   Units of National Currency Equivalent          Private Donations
# 232  Units of National Currency Equivalent  External Currency Charges
# 226  Units of National Currency Equivalent                 No Funding
# 227  Units of National Currency Equivalent                 No Funding
#
#                                purpose  membership
# 277              Community Development        50.0
# 95                         All reasons         NaN
# 119        Activating the Local Market       400.0
# 3                          All reasons       120.0
# 46                         All reasons       182.0
# 232  Reduce Need for National Currency        30.0
# 226  Reduce Need for National Currency        20.0
# 227                Poverty Alleviation        60.0
