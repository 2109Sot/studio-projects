# %%
import pandas as pd
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv("indie_data/Indiegogo016-05-14.csv")

# %%
df
# Out:
#             id                                              title  \
# 0       405885                                 Help Micky Recover
# 1       542014     BETTIS BOSTON TERRIER IN NEED OF A NUEROLOGIST
# 2       422637                                       Help Frankie
# 3       358194                             Help Our Kitty, Jester
# 4       327879                 Help Zhu Zhu Get Entropion Surgery
# 5      1413765              HELP HEAL GOTCHA THE BALI STREET DOG
# 6       497842                                    Bring Bear Home
# 7       123505  I demand 5 millions... Or I'm gonna devour thi...
# 8       326289                              All Pups Deserve Love
# 9      1293383                     Central Coast Earthlings Event
# 10     1079413                                     Pray for Annie
# 11      839423  Folly Farm's Team Zoo - making millions for mo...
# 12     1038968                                   Panda's delivery
# ...

# %%
df.dtypes
# Out:
# id                                 int64
# title                             object
# nearest_five_percent               int64
# tagline                           object
# cached_collected_pledges_count     int64
# igg_image_url                     object
# compressed_image_url              object
# balance                           object
# currency_code                     object
# amt_time_left                     object
# url                               object
# category_url                      object
# category_name                     object
# category_slug                     object
# card_type                         object
# collected_percentage              object
# partner_name                      object
# in_forever_funding                  bool
# friend_contributors               object
# friend_team_members               object
# source_url                        object
# dtype: object

# %%
pd.set_option("display.max_columns",100)

# %%
df['category_name'].value_counts()
# Out:
# Film           10129
# Community       8391
# Education       3650
# Art             3023
# Health          1693
# Animals         1628
# Environment      899
# Food             885
# Fashion          817
# Comic            525
# Gaming           466
# Design           440
# Dance            217
# Sports             1
# Name: category_name, dtype: int64

# %%
df[df['category_name'] == 'Art']
# Out:
#             id                                              title  \
# 707     285842         Client-generated, creative hallways spaces
# 708      25059                   Watercolor Art Card Subscription
# 709     517717                La boutique souvenirs Yes We Camp !
# 710    1302528                   Shapes and Chakras Coloring Book
# 711    1290619                      Kakophonium at The Borderland
# 712     113317         Keep The Spiral Alive and in San Francisco
# 713     787045            Queer and Trans Artist of Color Podcast
# 714     711246                                       My Next Book
# 715    1401713                      The Ministry of the Butterfly
# 716      29084                   Greenwood Lake Greetings Exhibit
# 717     946665            An Artistic Assessment of Altered Minds
# 718     375054  Lord Whitney and Jack Hudson present 'Mock n R...
# 719    1113011                 University of Waterloo - YES! 2015
# ...

# %%
import glob

# %%
files = glob.glob("indie_data/*.csv")
files
# Out:
# ['indie_data/Indiegogo001016-05-14.csv',
#  'indie_data/Indiegogo0012016-06-14.csv',
#  'indie_data/Indiegogo0012016-07-14.csv',
#  'indie_data/Indiegogo0012016-08-14.csv',
#  'indie_data/Indiegogo0012016-09-14.csv',
#  'indie_data/Indiegogo0012016-10-14.csv',
#  'indie_data/Indiegogo0012016-11-12.csv',
#  'indie_data/Indiegogo0012016-12-15.csv',
#  'indie_data/Indiegogo0012017-01-15.csv',
#  'indie_data/Indiegogo0012017-02-16.csv',
#  'indie_data/Indiegogo0012017-03-15.csv',
#  'indie_data/Indiegogo0012017-04-15.csv',
#  'indie_data/Indiegogo0012017-05-15.csv',
#  'indie_data/Indiegogo0012017-06-15.csv',
#  'indie_data/Indiegogo0012017-07-15.csv',
#  'indie_data/Indiegogo002016-05-14.csv',
#  'indie_data/Indiegogo0022016-06-14.csv',
#  'indie_data/Indiegogo0022016-07-14.csv',
#  'indie_data/Indiegogo0022016-08-14.csv',
#  'indie_data/Indiegogo0022016-09-14.csv',
#  'indie_data/Indiegogo0022016-10-14.csv',
#  'indie_data/Indiegogo0022016-11-12.csv',
# ...

# %%
art_dfs = [pd.read_csv(filename) for filename in files]
art_dfs
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
len(art_dfs)
# Out:
# 83

# %%
art_dfs[0].head(2)
# Out:
#        id                                           title  \
# 0  338423                            Envision the Mission
# 1  619000  Tacloban or Bust: Help Us Start Our Nonprofit!
#
#    nearest_five_percent                                            tagline  \
# 0                   100  Help Women’s Refugee Commission find & fund a ...
# 1                   100  We lack the trust funds to be bonafide philant...
#
#    cached_collected_pledges_count  \
# 0                              74
# 1                              47
#
#                                        igg_image_url  \
# 0  https://c1.iggcdn.com/indiegogo-media-prod-cld...
# 1  https://c1.iggcdn.com/indiegogo-media-prod-cld...
#
#                                 compressed_image_url balance currency_code  \
# 0  https://c1.iggcdn.com/indiegogo-media-prod-cld...  $4,045           USD
# 1  https://c1.iggcdn.com/indiegogo-media-prod-cld...  $4,041           USD
#
# ...

# %%
art_dfs[-1].head(2)
# Out:
#         id                                            title  \
# 0  2128945  Car Enthusiast- Love your cars, show the world.
# 1  2094827  Extraordinary Bumper 2 ways Backpack : X-Bumper
#
#    nearest_five_percent                                            tagline  \
# 0                     0  Clothing brand for people with passion for car...
# 1                    15  X-Bumper features all the benefits of really c...
#
#    cached_collected_pledges_count  \
# 0                               0
# 1                               8
#
#                                        igg_image_url  \
# 0  https://c1.iggcdn.com/indiegogo-media-prod-cld...
# 1  https://c1.iggcdn.com/indiegogo-media-prod-cld...
#
#                                 compressed_image_url balance currency_code  \
# 0  https://c1.iggcdn.com/indiegogo-media-prod-cld...      $0           USD
# 1  https://c1.iggcdn.com/indiegogo-media-prod-cld...    $930           USD
#
# ...

# %%
final_df = pd.concat([df for df in art_dfs], ignore_index = True)

# %%
final_df.shape
# Out:
# (2295181, 21)

# %%
final_df.head()
# Out:
#         id                                           title  \
# 0   338423                            Envision the Mission
# 1   619000  Tacloban or Bust: Help Us Start Our Nonprofit!
# 2  1017408        Bringing back Yogic gifts from Guatemala
# 3   725706                          Help Mason go to Nepal
# 4   546847                          City Kids Take Flight!
#
#    nearest_five_percent                                            tagline  \
# 0                   100  Help Women’s Refugee Commission find & fund a ...
# 1                   100  We lack the trust funds to be bonafide philant...
# 2                    80  Raising money for my Advanced Yoga Teacher Tra...
# 3                    90  I have been awarded a grant to go to Nepal, bu...
# 4                    80  Make global connections a reality for 28 city ...
#
#    cached_collected_pledges_count  \
# 0                              74
# 1                              47
# 2                              60
# ...

# %%
indie_final_df = final_df[final_df['category_name'] == 'Art']

# %%
indie_final_df.shape
# Out:
# (100552, 21)

# %%
indie_final_df.to_csv("INDIEGOGO_ART.csv", index=False)

# %%
indie_final_df[indie_final_df['amt_time_left'] == 'No time left']
# Out:
#               id                                              title  \
# 9945     1702880                                     Bigfoot Patrol
# 10030    1580802                          Face The Impossible, FLY!
# 16336     369775                           Help Jade's Summer Blow!
# 16337    1497716       Werewolf Queen miniature - Michael Kontraros
# 16338     732161                                Send Erika to Icon8
# 16339     397416           Montreal Artbook - Discoveries: Montreal
# 16340    1041364     Help Propel Chelsea Rose Art: A Small Business
# 16341     192331              Neighborhood Playhouse Apprenticeship
# 16342     301931                  Flyover Press Letterpress Posters
# 16343     171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 16344     994287              Plant Encounters: a roaming residency
# 16345     687011                                    WINTER magazine
# 16346    1002586             This got to be BANNED.Maurycy Lozinski
# ...

# %%
indie_update_final = indie_final_df[indie_final_df['amt_time_left'] == 'No time left']

# %%
indie_update_final
# Out:
#               id                                              title  \
# 9945     1702880                                     Bigfoot Patrol
# 10030    1580802                          Face The Impossible, FLY!
# 16336     369775                           Help Jade's Summer Blow!
# 16337    1497716       Werewolf Queen miniature - Michael Kontraros
# 16338     732161                                Send Erika to Icon8
# 16339     397416           Montreal Artbook - Discoveries: Montreal
# 16340    1041364     Help Propel Chelsea Rose Art: A Small Business
# 16341     192331              Neighborhood Playhouse Apprenticeship
# 16342     301931                  Flyover Press Letterpress Posters
# 16343     171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 16344     994287              Plant Encounters: a roaming residency
# 16345     687011                                    WINTER magazine
# 16346    1002586             This got to be BANNED.Maurycy Lozinski
# ...

# %%
indie_update_final.to_csv("INDIE_ART.csv", index=False)

# %%
indie_notime = pd.read_csv("INDIE_ART.csv")

# %%
indie_notime
# Out:
#             id                                              title  \
# 0      1702880                                     Bigfoot Patrol
# 1      1580802                          Face The Impossible, FLY!
# 2       369775                           Help Jade's Summer Blow!
# 3      1497716       Werewolf Queen miniature - Michael Kontraros
# 4       732161                                Send Erika to Icon8
# 5       397416           Montreal Artbook - Discoveries: Montreal
# 6      1041364     Help Propel Chelsea Rose Art: A Small Business
# 7       192331              Neighborhood Playhouse Apprenticeship
# 8       301931                  Flyover Press Letterpress Posters
# 9       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 10      994287              Plant Encounters: a roaming residency
# 11      687011                                    WINTER magazine
# 12     1002586             This got to be BANNED.Maurycy Lozinski
# ...

# %%
indie_notime[indie_notime['currency_code'] == 'USD']
# Out:
#             id                                              title  \
# 0      1702880                                     Bigfoot Patrol
# 1      1580802                          Face The Impossible, FLY!
# 2       369775                           Help Jade's Summer Blow!
# 4       732161                                Send Erika to Icon8
# 6      1041364     Help Propel Chelsea Rose Art: A Small Business
# 7       192331              Neighborhood Playhouse Apprenticeship
# 8       301931                  Flyover Press Letterpress Posters
# 9       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 10      994287              Plant Encounters: a roaming residency
# 14      189653                              2013 Fantasy Calendar
# 16      977742                        DJ Akademiks Weekly Podcast
# 17      828916          Cloud 9 Mutant Vehicle - Burning Man 2014
# 18     1105495                                    Modern Myth-Mix
# ...

# %%
indie_final_update = indie_notime[indie_notime['currency_code'] == 'USD']

# %%
indie_final_update
# Out:
#             id                                              title  \
# 0      1702880                                     Bigfoot Patrol
# 1      1580802                          Face The Impossible, FLY!
# 2       369775                           Help Jade's Summer Blow!
# 4       732161                                Send Erika to Icon8
# 6      1041364     Help Propel Chelsea Rose Art: A Small Business
# 7       192331              Neighborhood Playhouse Apprenticeship
# 8       301931                  Flyover Press Letterpress Posters
# 9       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 10      994287              Plant Encounters: a roaming residency
# 14      189653                              2013 Fantasy Calendar
# 16      977742                        DJ Akademiks Weekly Podcast
# 17      828916          Cloud 9 Mutant Vehicle - Burning Man 2014
# 18     1105495                                    Modern Myth-Mix
# ...

# %%
indie_final_update.to_csv("INDIE_ARTS.csv", index=False)

# %%
indie_funding = pd.read_csv("INDIE_ARTS.csv")

# %%
indie_funding
# Out:
#             id                                              title  \
# 0      1702880                                     Bigfoot Patrol
# 1      1580802                          Face The Impossible, FLY!
# 2       369775                           Help Jade's Summer Blow!
# 3       732161                                Send Erika to Icon8
# 4      1041364     Help Propel Chelsea Rose Art: A Small Business
# 5       192331              Neighborhood Playhouse Apprenticeship
# 6       301931                  Flyover Press Letterpress Posters
# 7       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 8       994287              Plant Encounters: a roaming residency
# 9       189653                              2013 Fantasy Calendar
# 10      977742                        DJ Akademiks Weekly Podcast
# 11      828916          Cloud 9 Mutant Vehicle - Burning Man 2014
# 12     1105495                                    Modern Myth-Mix
# ...

# %%
indie_funding[indie_funding['in_forever_funding'] == False]
# Out:
#             id                                              title  \
# 2       369775                           Help Jade's Summer Blow!
# 3       732161                                Send Erika to Icon8
# 4      1041364     Help Propel Chelsea Rose Art: A Small Business
# 5       192331              Neighborhood Playhouse Apprenticeship
# 6       301931                  Flyover Press Letterpress Posters
# 7       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 8       994287              Plant Encounters: a roaming residency
# 9       189653                              2013 Fantasy Calendar
# 10      977742                        DJ Akademiks Weekly Podcast
# 11      828916          Cloud 9 Mutant Vehicle - Burning Man 2014
# 12     1105495                                    Modern Myth-Mix
# 13      206081  HAVE COMPANY & Bethlehem , NH : experiencing a...
# 14      849570    Send M'Vyonne Payne to the National Poetry Slam
# ...

# %%
indie_funding_final = indie_funding[indie_funding['in_forever_funding'] == False]

# %%
indie_funding_final
# Out:
#             id                                              title  \
# 2       369775                           Help Jade's Summer Blow!
# 3       732161                                Send Erika to Icon8
# 4      1041364     Help Propel Chelsea Rose Art: A Small Business
# 5       192331              Neighborhood Playhouse Apprenticeship
# 6       301931                  Flyover Press Letterpress Posters
# 7       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 8       994287              Plant Encounters: a roaming residency
# 9       189653                              2013 Fantasy Calendar
# 10      977742                        DJ Akademiks Weekly Podcast
# 11      828916          Cloud 9 Mutant Vehicle - Burning Man 2014
# 12     1105495                                    Modern Myth-Mix
# 13      206081  HAVE COMPANY & Bethlehem , NH : experiencing a...
# 14      849570    Send M'Vyonne Payne to the National Poetry Slam
# ...

# %%
indie_funding_final.to_csv("INDIE_ART_FUNDING.csv", index=False)

# %%
indie_succesfull = indie_funding_final[indie_funding_final['collected_percentage'] >= '100%']

# %%
indie_succesfull
# Out:
#             id                                              title  \
# 2       369775                           Help Jade's Summer Blow!
# 3       732161                                Send Erika to Icon8
# 4      1041364     Help Propel Chelsea Rose Art: A Small Business
# 5       192331              Neighborhood Playhouse Apprenticeship
# 6       301931                  Flyover Press Letterpress Posters
# 7       171773          Cloud 9 Mutant Vehicle - Burning Man 2012
# 8       994287              Plant Encounters: a roaming residency
# 9       189653                              2013 Fantasy Calendar
# 10      977742                        DJ Akademiks Weekly Podcast
# 11      828916          Cloud 9 Mutant Vehicle - Burning Man 2014
# 12     1105495                                    Modern Myth-Mix
# 13      206081  HAVE COMPANY & Bethlehem , NH : experiencing a...
# 14      849570    Send M'Vyonne Payne to the National Poetry Slam
# ...

# %%
indie_succesfull.to_csv("INDIEGOGO_ART_FINAL.csv")

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
import requests

# %%
# def process_entry(row):
#     driver = webdriver.Chrome()
#     driver.get("https://www.indiegogo.com" + row['url'])
#     project_title = driver.find_element_by_xpath('/html/body/div[2]/div/div/campaign-page/div/div/campaign-header-basics/div/div[1]/div[1]')
#     if project_title:
#         print('title:', project_title.text.strip())
#     project_backers = driver.find_element_by_xpath('/html/body/div[2]/div/div/campaign-page/div/div/campaign-header-basics/div/div[2]/div/campaign-goal-progress/div/div[1]/span[2]')
#     if project_backers:
#         print('backers_count:', project_backers.text.strip())
#     project_location = driver.find_element_by_xpath('/html/body/div[2]/div/div/campaign-page/div/div/campaign-header-basics/div/div[1]/div[3]/campaign-header-trust/div/purchasable-trust/div/div/div[2]')
#     if project_location:
#         print('location:', project_location.text.strip())
#     print("-----")
        
# df.apply(process_entry, axis=1)

# %%
indie_succesfull['balance'] = indie_succesfull['balance'].str.replace('$', "")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
indie_succesfull.head()
# Out:
#         id                                           title  \
# 2   369775                        Help Jade's Summer Blow!
# 3   732161                             Send Erika to Icon8
# 4  1041364  Help Propel Chelsea Rose Art: A Small Business
# 5   192331           Neighborhood Playhouse Apprenticeship
# 6   301931               Flyover Press Letterpress Posters
#
#    nearest_five_percent                                            tagline  \
# 2                   100  I've received a scholarship to take a class wi...
# 3                   100  In order to help me to develop my budding care...
# 4                   100  The next step for Chelsea Rose Art could be Ar...
# 5                   100  Stephanie Jones OAC Chalmers award follow-up a...
# 6                   100  Midwestern-inspired letterpress posters, desig...
#
#    cached_collected_pledges_count  \
# 2                              26
# 3                              27
# 4                              29
# ...

# %%
indie_succesfull['balance'] = indie_succesfull['balance'].str.replace(',', "")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
indie_succesfull['balance'] = indie_succesfull['balance'].astype(int)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
indie_succesfull.dtypes
# Out:
# id                                 int64
# title                             object
# nearest_five_percent               int64
# tagline                           object
# cached_collected_pledges_count     int64
# igg_image_url                     object
# compressed_image_url              object
# balance                            int64
# currency_code                     object
# amt_time_left                     object
# url                               object
# category_url                      object
# category_name                     object
# category_slug                     object
# card_type                         object
# collected_percentage              object
# partner_name                      object
# in_forever_funding                  bool
# friend_contributors               object
# friend_team_members               object
# source_url                        object
# dtype: object

# %%
indie_succesfull['balance'].sum()
# Out:
# 221434370
