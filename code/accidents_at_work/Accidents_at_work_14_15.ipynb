# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

# %% [markdown]
# # 2014

# %%
sector_region_14 = pd.read_excel("economic_activity_14.xlsx")
sector_region_14
# Out:
#                                                sector  number_of_accidents14
# 0                   Agriculture, forestry and fishing                     94
# 1                                Mining and quarrying                     79
# 2                                       Manufacturing                    883
# 3   Electricity, gas, steam and air conditioning s...                     71
# 4   Water supply; sewerage, waste management and r...                    164
# 5                                        Construction                    453
# 6   Wholesale and retail trade; repair of motor ve...                    995
# 7                          Transportation and storage                    402
# 8           Accommodation and food service activities                    482
# 9                       Information and communication                     70
# 10                 Financial and insurance activities                     27
# ...

# %%
sector_region_14.groupby('sector')['number_of_accidents14'].sum().sort_values().plot(kind='barh', figsize=(10,10))

# %% [markdown]
# # 2015

# %%
sector_region_15 = pd.read_excel("economic_activity_15.xlsx")
sector_region_15
# Out:
#                                                sector  number_of_accidents15
# 0                   Agriculture, forestry and fishing                     96
# 1                                Mining and quarrying                     87
# 2                                       Manufacturing                    911
# 3   Electricity, gas, steam and air conditioning s...                     98
# 4   Water supply; sewerage, waste management and r...                    172
# 5                                        Construction                    412
# 6   Wholesale and retail trade; repair of motor ve...                    968
# 7                          Transportation and storage                    409
# 8           Accommodation and food service activities                    550
# 9                       Information and communication                    104
# 10                 Financial and insurance activities                     28
# ...

# %%
sector_region_15.groupby('sector')['number_of_accidents15'].sum().sort_values().plot(kind='barh', figsize=(10,10))

# %%
combined_df = sector_region_14.merge(sector_region_15, how='left', on='sector')
combined_df.head()
# Out:
#                                               sector  number_of_accidents14  \
# 0                  Agriculture, forestry and fishing                     94
# 1                               Mining and quarrying                     79
# 2                                      Manufacturing                    883
# 3  Electricity, gas, steam and air conditioning s...                     71
# 4  Water supply; sewerage, waste management and r...                    164
#
#    number_of_accidents15
# 0                     96
# 1                     87
# 2                    911
# 3                     98
# 4                    172

# %%
combined_df.set_index('sector', inplace=True)
combined_df.head()
# Out:
#                                                     number_of_accidents14  \
# sector
# Agriculture, forestry and fishing                                      94
# Mining and quarrying                                                   79
# Manufacturing                                                         883
# Electricity, gas, steam and air conditioning su...                     71
# Water supply; sewerage, waste management and re...                    164
#
#                                                     number_of_accidents15
# sector
# Agriculture, forestry and fishing                                      96
# Mining and quarrying                                                   87
# Manufacturing                                                         911
# Electricity, gas, steam and air conditioning su...                     98
# Water supply; sewerage, waste management and re...                    172

# %%
combined_df.plot(kind='barh', figsize=(10,5))

plt.savefig('sector_total_14_15.pdf')

# %%
occupation_14_15 = pd.read_excel("occupation_14_15.xlsx")
occupation_14_15

# %%
lalala = pd.read_excel("occupation_14_15.xlsx")
lalala

# %%
lalala.set_index('occupation', inplace=True)
lalala

# %%
lalala.plot(kind='barh')
plt.savefig('oc_14_15.pdf')

# %%
bodyparts = pd.read_excel("body_total_05_15.xlsx")
bodyparts

# %%
bodyparts.set_index('wounded_part_of_body', inplace=True)

# %%
bodyparts.sort_values(by='tot').plot(kind='barh')

plt.savefig('bodyparts_total.pdf')

# %%
injuries = pd.read_excel("injury_type_05_15.xlsx")
injuries

# %%
injuries.set_index('type_of_wound', inplace=True)

# %%
injuries.sort_values(by='total').plot(kind='barh')

plt.savefig('injuries_total.pdf')

# %%
injuries
